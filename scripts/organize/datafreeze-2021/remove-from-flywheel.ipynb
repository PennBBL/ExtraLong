# %%
import logging
import numpy as np
import pandas as pd
import flywheel

# %%
# Instantiate a logger
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s %(message)s')
log = logging.getLogger('root')

# %%
# # Get API_KEY from FW profile
API_KEY = "upenn.flywheel.io:47vhOSDkwMxGRNxFq0"

# Get client
fw = flywheel.Client(API_KEY)
assert fw, "Your Flywheel CLI credentials aren't set!"

# %%
# Metadata for new project 
GROUP = "BBL"
PROJECT_LABEL = "ExtraLong_2021"
project = fw.projects.find_first('label="{}"'.format(PROJECT_LABEL))
assert project, "Project not found!"
# Out:
# /Users/kzoner/.conda/envs/flywheel/lib/python3.8/site-packages/flywheel/flywheel.py:6274: UserWarning: Client version 15.3.1 does not match server version 14.6.4. Please update your client version!
#   warnings.warn('Client version {} does not match server version {}. Please update your client version!'.format(SDK_VERSION, release_version))
# 2021-09-20 13:11:32,320 WARNING Use "pip install flywheel-sdk~=14.6.5" to install a compatible version for this server

# %%
def filterBySessionCount(df, thresh):

    # Get scan counts for each subject (bblid).
    bblid_counts = df.groupby(["bblid"]).size().reset_index()
    bblid_counts.columns = ["bblid", "scan_count"]
    bblid_counts.sort_values("scan_count")

    # Get list of bblids that should be included
    include_bblids = bblid_counts.bblid[bblid_counts["scan_count"]>=thresh]

    # Filter dataframe to only include subjects that meet session requirements
    df = df[df["bblid"].isin(include_bblids)].copy()

    # Update ntimepoints column to indicate number of sessions in ExtraLong 2021 for each subject.
    for bblid in df.bblid.unique():

        # Get subject's number of timepoints in ExtraLong 2021
        num_tps = bblid_counts[bblid_counts.bblid == bblid].scan_count.item()

        # Update ntimeponts in ExtraLong dataframe
        df.loc[df.bblid==bblid, 'ntimepoints'] = num_tps

    # Update timepoint column to indicate timepoint number for each subject
    df["timepoint"] = df.groupby("bblid").cumcount()+1

    return df.sort_values(["bblid","doscan"])

# %%
def get_row_diff(bigger, smaller):
    return bigger[(~bigger.scanid.isin(smaller.scanid))]

# %%
def getSession(scan):
    sub = project.subjects.find_first(f"label=sub-{scan.bblid}")
    if sub:
        ses = sub.sessions.find_first(f"label=ses-{scan.sesid}{scan.timepoint}")
        if ses:
            return ses
        else:
            print(f"Subject {scan.bblid} Session {scan.sesid} not found on Flywheel!")
    else:
            print(f"Subject {scan.bblid} not found on Flywheel!")

# %%
def getSubject(bblid):
    sub = project.subjects.find_first(f"label=sub-{bblid}")
    if sub:
        return sub
    else:
        print(f"Subject sub-{bblid} not found on Flywheel!")

# %%
def delete_session(session, dry_run=True):
    """Returns True if session got deleted.
    
    Args:
        session (object): A Flywheel Session.
        dry_run (bool): If true, container is not deleted.    
        
    Returns:
        bool: True if container got deleted, False otherwise.
    """        
    log.info(f'Deleting session "{session.label}" from subject {session.subject.label}')
    if not dry_run:
        fw.delete_session(session.id)
        return True
    return False

# %%
def delete_empty_subject(subject, dry_run=True):
    """Returns True if subject was empty and got deleted.
    
    Args:
        subject (object): A Flywheel Subject.
        dry_run (bool): If true, container is not deleted.    
        
    Returns:
        bool: True if container got deleted, False otherwise.
    """        
    log.info(f'Checking if subject "{subject.label}" is empty')
    num_sessions = len(subject.sessions())
    log.info(f'Found {num_sessions} sessions')    
    delete_subject = (num_sessions == 0)
    if delete_subject:
        log.info(f'Deleting subject "{subject.label}"')
        if not dry_run:        
            fw.delete_subject(subject.id)
    return delete_subject

# %% [markdown]
# ## Dataset should only include subjects with 2+ timepoints. Subjects should be < 35 yrs old at all timepoints.
# ### 1. Filter csv to find subjects

# %%
# Read in ExtraLong 2021 csv
fname = "./csv/ExtraLong-Datafreeze-20210831.csv"
xl = pd.read_csv(fname)
#xl.sort_values(by=['bblid','timepoint'],inplace=True)
xl
# Out:
#        bblid  scanid  sesid    scan_protocol    project  \
# 0      10410    6776   FNDM    810211 - FNDM  ExtraLong
# 1      10410    6843   FNDM    810211 - FNDM  ExtraLong
# 2      11186    3395    DAY    808799 - DAY2  ExtraLong
# 3      11186    6378   FNDM    810211 - FNDM  ExtraLong
# 4      11242    3360    DAY    808799 - DAY2  ExtraLong
# ...      ...     ...    ...              ...        ...
# 2587  139272   10109  GRMPY   822831 - GRMPY  ExtraLong
# 2588  139490    8461    PNC  810336 - Big GO  ExtraLong
# 2589  139490   10564  CONTE   815814 - Conte  ExtraLong
# 2590  139553    8410    PNC  810336 - Big GO  ExtraLong
# 2591  139553    9822    PNC     810336 - Go3  ExtraLong
#
#                                        filename                     acqid  \
# 0               sub-10410_ses-FNDM11_T1w.nii.gz  5d9e0666a54d350038b39e11
# 1               sub-10410_ses-FNDM21_T1w.nii.gz  5d9e0972a54d350044c11e33
# 2                sub-11186_ses-DAY21_T1w.nii.gz  5d9dfb8ba54d350042bd8142
# 3               sub-11186_ses-FNDM21_T1w.nii.gz  5d9e0c47a54d350042bd95b4
# 4                sub-11242_ses-DAY21_T1w.nii.gz  5d9dfb97a54d35003eb7f374
# ...                                         ...                       ...
# 2587            sub-139272_ses-10109_T1w.nii.gz  5d9cac7ea54d35003eb749f4
# 2588             sub-139490_ses-PNC1_T1w.nii.gz  5d9cd114a54d350039b28ece
# 2589  sub-139490_ses-CONTE1_acq-moco_T1w.nii.gz  5d9ca3cfa54d350028b04b1d
# 2590             sub-139553_ses-PNC1_T1w.nii.gz  5d9d14b1a54d350042bcbddd
# 2591             sub-139553_ses-PNC2_T1w.nii.gz  5d9f6460ccb6a50054468422
#
#           doscan  timepoint  ntimepoints  scanage_months  sex  race  ethnic
# 0     2012-04-24          1            2           556.0  2.0   2.0     2.0
# 1     2012-05-11          2            2           557.0  2.0   2.0     2.0
# 2     2010-06-10          1            2           534.0  1.0   1.0     2.0
# 3     2012-02-03          2            2           554.0  1.0   1.0     2.0
# 4     2010-06-02          1            2           694.0  1.0   1.0     2.0
# ...          ...        ...          ...             ...  ...   ...     ...
# 2587  2016-04-07          6            6           259.0  2.0   2.0     2.0
# 2588  2013-08-30          1            2           105.0  1.0   2.0     2.0
# 2589  2017-04-29          2            2           149.0  1.0   2.0     2.0
# 2590  2013-08-23          1            2           107.0  2.0   2.0     2.0
# 2591  2015-09-12          2            2           132.0  2.0   2.0     2.0
#
# [2592 rows x 14 columns]

# %%
# Get age maximum in months: 35 years old * 12 months
max_age = 35 * 12 

# Filter xl to only include subjects < 35 years old with 2+ sessions
keep = xl[xl.scanage_months < max_age].copy()
keep_filtered = filterBySessionCount(keep, 2)

# Get dataframe of sessions to remove based on age / not meeting session count
remove = xl[xl.scanage_months >= max_age]
remove = remove.append(get_row_diff(keep,keep_filtered))
remove
# Out:
#        bblid  scanid sesid            scan_protocol    project  \
# 0      10410    6776  FNDM            810211 - FNDM  ExtraLong
# 1      10410    6843  FNDM            810211 - FNDM  ExtraLong
# 2      11186    3395   DAY            808799 - DAY2  ExtraLong
# 3      11186    6378  FNDM            810211 - FNDM  ExtraLong
# 4      11242    3360   DAY            808799 - DAY2  ExtraLong
# ...      ...     ...   ...                      ...        ...
# 361    17962    8436  FNDM            810211 - FNDM  ExtraLong
# 364    18013    8532  FNDM            810211 - FNDM  ExtraLong
# 365    18013    8549  FNDM            810211 - FNDM  ExtraLong
# 1808  110689    6027   PNC          810336 - Big GO  ExtraLong
# 1809  110689    8212   PNC  810336 - Go2 Supplement  ExtraLong
#
#                              filename                     acqid      doscan  \
# 0     sub-10410_ses-FNDM11_T1w.nii.gz  5d9e0666a54d350038b39e11  2012-04-24
# 1     sub-10410_ses-FNDM21_T1w.nii.gz  5d9e0972a54d350044c11e33  2012-05-11
# 2      sub-11186_ses-DAY21_T1w.nii.gz  5d9dfb8ba54d350042bd8142  2010-06-10
# 3     sub-11186_ses-FNDM21_T1w.nii.gz  5d9e0c47a54d350042bd95b4  2012-02-03
# 4      sub-11242_ses-DAY21_T1w.nii.gz  5d9dfb97a54d35003eb7f374  2010-06-02
# ...                               ...                       ...         ...
# 361   sub-17962_ses-FNDM21_T1w.nii.gz  5d9e0c21a54d350044c12343  2013-08-26
# 364   sub-18013_ses-FNDM11_T1w.nii.gz  5d9e08e0a54d35003cb5bcef  2013-09-30
# 365   sub-18013_ses-FNDM21_T1w.nii.gz  5d9e0c37a54d350044c12376  2013-10-04
# 1808   sub-110689_ses-PNC1_T1w.nii.gz  5d9d026da54d350044c00c83  2011-11-12
# 1809   sub-110689_ses-PNC2_T1w.nii.gz  5d9f417eccb6a50054465bcd  2013-07-11
#
#       timepoint  ntimepoints  scanage_months  sex  race  ethnic
# 0             1            2           556.0  2.0   2.0     2.0
# 1             2            2           557.0  2.0   2.0     2.0
# 2             1            2           534.0  1.0   1.0     2.0
# 3             2            2           554.0  1.0   1.0     2.0
# 4             1            2           694.0  1.0   1.0     2.0
# ...         ...          ...             ...  ...   ...     ...
# 361           2            2           434.0  2.0   NaN     NaN
# 364           1            2           593.0  2.0   1.0     2.0
# 365           2            2           593.0  2.0   1.0     2.0
# 1808          1            2           521.0  1.0   NaN     NaN
# 1809          2            2           541.0  1.0   NaN     NaN
#
# [137 rows x 14 columns]

# %% [markdown]
# # DO THE DELETING!!

# %%
# 1. For each session in remove df, remove session from Flywheel.
for row in remove.itertuples():
    ses = getSession(row)
    if ses:
        delete_session(ses, dry_run=False)
# Out:
# Subject 10410 not found on Flywheel!
# Subject 10410 not found on Flywheel!
# 2021-09-20 14:20:56,768 INFO Deleting session "ses-DAY1" from subject sub-11186
# 2021-09-20 14:20:57,762 INFO Deleting session "ses-FNDM2" from subject sub-11186
# 2021-09-20 14:20:58,959 INFO Deleting session "ses-DAY1" from subject sub-11242
# 2021-09-20 14:20:59,845 INFO Deleting session "ses-FNDM2" from subject sub-11242
# 2021-09-20 14:21:00,660 INFO Deleting session "ses-FNDM3" from subject sub-11399
# 2021-09-20 14:21:01,426 INFO Deleting session "ses-NEFF4" from subject sub-11399
# 2021-09-20 14:21:02,459 INFO Deleting session "ses-DAY1" from subject sub-11419
# 2021-09-20 14:21:03,208 INFO Deleting session "ses-FNDM2" from subject sub-11419
# 2021-09-20 14:21:04,012 INFO Deleting session "ses-DAY1" from subject sub-11569
# 2021-09-20 14:21:05,131 INFO Deleting session "ses-FNDM2" from subject sub-11569
# 2021-09-20 14:21:07,408 INFO Deleting session "ses-FNDM3" from subject sub-11569
# 2021-09-20 14:21:10,098 INFO Deleting session "ses-DAY1" from subject sub-11599
# 2021-09-20 14:21:11,157 INFO Deleting session "ses-FNDM2" from subject sub-11599
# 2021-09-20 14:21:12,194 INFO Deleting session "ses-NEFF3" from subject sub-11599
# 2021-09-20 14:21:13,244 INFO Deleting session "ses-DAY1" from subject sub-11762
# 2021-09-20 14:21:13,984 INFO Deleting session "ses-FNDM2" from subject sub-11762
# 2021-09-20 14:21:14,844 INFO Deleting session "ses-DAY1" from subject sub-11866
# 2021-09-20 14:21:15,971 INFO Deleting session "ses-FNDM2" from subject sub-11866
# 2021-09-20 14:21:16,995 INFO Deleting session "ses-FNDM3" from subject sub-11866
# 2021-09-20 14:21:18,017 INFO Deleting session "ses-DAY1" from subject sub-12285
# 2021-09-20 14:21:18,939 INFO Deleting session "ses-FNDM2" from subject sub-12285
# 2021-09-20 14:21:20,282 INFO Deleting session "ses-DAY1" from subject sub-12498
# 2021-09-20 14:21:22,628 INFO Deleting session "ses-FNDM2" from subject sub-12498
# 2021-09-20 14:21:23,855 INFO Deleting session "ses-DAY1" from subject sub-12583
# 2021-09-20 14:21:24,982 INFO Deleting session "ses-FNDM2" from subject sub-12583
# 2021-09-20 14:21:26,109 INFO Deleting session "ses-DAY1" from subject sub-12738
# 2021-09-20 14:21:27,133 INFO Deleting session "ses-FNDM2" from subject sub-12738
# 2021-09-20 14:21:28,158 INFO Deleting session "ses-FNDM3" from subject sub-12738
# 2021-09-20 14:21:28,956 INFO Deleting session "ses-DAY1" from subject sub-12740
# 2021-09-20 14:21:29,895 INFO Deleting session "ses-FNDM2" from subject sub-12740
# 2021-09-20 14:21:31,024 INFO Deleting session "ses-FNDM3" from subject sub-12740
# 2021-09-20 14:21:32,047 INFO Deleting session "ses-DAY1" from subject sub-12822
# 2021-09-20 14:21:33,172 INFO Deleting session "ses-FNDM2" from subject sub-12822
# 2021-09-20 14:21:34,196 INFO Deleting session "ses-FNDM3" from subject sub-12822
# 2021-09-20 14:21:35,016 INFO Deleting session "ses-DAY1" from subject sub-12938
# 2021-09-20 14:21:35,939 INFO Deleting session "ses-FNDM2" from subject sub-12938
# 2021-09-20 14:21:36,965 INFO Deleting session "ses-FNDM1" from subject sub-13372
# 2021-09-20 14:21:38,395 INFO Deleting session "ses-FNDM2" from subject sub-13372
# 2021-09-20 14:21:39,226 INFO Deleting session "ses-NEFF3" from subject sub-13372
# 2021-09-20 14:21:40,153 INFO Deleting session "ses-NEFF2" from subject sub-13394
# 2021-09-20 14:21:41,162 INFO Deleting session "ses-DAY1" from subject sub-13548
# 2021-09-20 14:21:41,899 INFO Deleting session "ses-FNDM2" from subject sub-13548
# 2021-09-20 14:21:42,798 INFO Deleting session "ses-DAY1" from subject sub-14805
# 2021-09-20 14:21:43,721 INFO Deleting session "ses-FNDM2" from subject sub-14805
# 2021-09-20 14:21:44,642 INFO Deleting session "ses-NEFF3" from subject sub-14805
# 2021-09-20 14:21:45,726 INFO Deleting session "ses-DAY1" from subject sub-15311
# 2021-09-20 14:21:46,755 INFO Deleting session "ses-FNDM2" from subject sub-15311
# 2021-09-20 14:21:47,866 INFO Deleting session "ses-DAY1" from subject sub-15426
# 2021-09-20 14:21:48,981 INFO Deleting session "ses-FNDM2" from subject sub-15426
# 2021-09-20 14:21:49,973 INFO Deleting session "ses-DAY1" from subject sub-15428
# 2021-09-20 14:21:51,092 INFO Deleting session "ses-FNDM2" from subject sub-15428
# 2021-09-20 14:21:52,220 INFO Deleting session "ses-DAY1" from subject sub-15444
# 2021-09-20 14:21:53,346 INFO Deleting session "ses-FNDM2" from subject sub-15444
# 2021-09-20 14:21:54,269 INFO Deleting session "ses-FNDM3" from subject sub-15444
# 2021-09-20 14:21:54,986 INFO Deleting session "ses-DAY1" from subject sub-15628
# 2021-09-20 14:21:56,113 INFO Deleting session "ses-FNDM2" from subject sub-15628
# 2021-09-20 14:21:56,931 INFO Deleting session "ses-DAY1" from subject sub-15630
# 2021-09-20 14:21:57,725 INFO Deleting session "ses-FNDM2" from subject sub-15630
# 2021-09-20 14:21:58,467 INFO Deleting session "ses-FNDM2" from subject sub-15688
# 2021-09-20 14:21:59,386 INFO Deleting session "ses-NEFF3" from subject sub-15688
# 2021-09-20 14:22:00,105 INFO Deleting session "ses-DAY1" from subject sub-15802
# 2021-09-20 14:22:00,923 INFO Deleting session "ses-FNDM2" from subject sub-15802
# 2021-09-20 14:22:01,727 INFO Deleting session "ses-DAY1" from subject sub-16206
# 2021-09-20 14:22:02,562 INFO Deleting session "ses-FNDM2" from subject sub-16206
# 2021-09-20 14:22:03,380 INFO Deleting session "ses-DAY1" from subject sub-16234
# 2021-09-20 14:22:04,100 INFO Deleting session "ses-FNDM2" from subject sub-16234
# 2021-09-20 14:22:05,120 INFO Deleting session "ses-DAY1" from subject sub-16239
# 2021-09-20 14:22:06,044 INFO Deleting session "ses-FNDM2" from subject sub-16239
# 2021-09-20 14:22:07,170 INFO Deleting session "ses-FNDM3" from subject sub-16239
# 2021-09-20 14:22:08,195 INFO Deleting session "ses-NEFF1" from subject sub-16336
# 2021-09-20 14:22:09,011 INFO Deleting session "ses-NEFF2" from subject sub-16336
# 2021-09-20 14:22:09,936 INFO Deleting session "ses-FNDM1" from subject sub-16382
# 2021-09-20 14:22:11,061 INFO Deleting session "ses-FNDM2" from subject sub-16382
# 2021-09-20 14:22:11,929 INFO Deleting session "ses-FNDM1" from subject sub-16492
# 2021-09-20 14:22:13,006 INFO Deleting session "ses-FNDM2" from subject sub-16492
# 2021-09-20 14:22:14,029 INFO Deleting session "ses-DAY1" from subject sub-16603
# 2021-09-20 14:22:15,055 INFO Deleting session "ses-FNDM2" from subject sub-16603
# 2021-09-20 14:22:16,079 INFO Deleting session "ses-DAY1" from subject sub-16661
# 2021-09-20 14:22:17,104 INFO Deleting session "ses-FNDM2" from subject sub-16661
# 2021-09-20 14:22:18,127 INFO Deleting session "ses-ONM3" from subject sub-16661
# 2021-09-20 14:22:19,047 INFO Deleting session "ses-DAY1" from subject sub-16662
# 2021-09-20 14:22:20,054 INFO Deleting session "ses-FNDM2" from subject sub-16662
# 2021-09-20 14:22:20,994 INFO Deleting session "ses-FNDM1" from subject sub-16668
# 2021-09-20 14:22:21,676 INFO Deleting session "ses-FNDM2" from subject sub-16668
# 2021-09-20 14:22:22,735 INFO Deleting session "ses-FNDM1" from subject sub-16717
# 2021-09-20 14:22:23,861 INFO Deleting session "ses-FNDM2" from subject sub-16717
# 2021-09-20 14:22:24,987 INFO Deleting session "ses-FNDM1" from subject sub-16809
# 2021-09-20 14:22:25,909 INFO Deleting session "ses-FNDM2" from subject sub-16809
# 2021-09-20 14:22:27,138 INFO Deleting session "ses-FNDM1" from subject sub-17028
# 2021-09-20 14:22:28,163 INFO Deleting session "ses-FNDM2" from subject sub-17028
# 2021-09-20 14:22:29,186 INFO Deleting session "ses-FNDM1" from subject sub-17096
# 2021-09-20 14:22:30,217 INFO Deleting session "ses-FNDM2" from subject sub-17096
# 2021-09-20 14:22:31,073 INFO Deleting session "ses-FNDM1" from subject sub-17108
# 2021-09-20 14:22:32,055 INFO Deleting session "ses-FNDM2" from subject sub-17108
# 2021-09-20 14:22:33,179 INFO Deleting session "ses-FNDM1" from subject sub-17155
# 2021-09-20 14:22:34,100 INFO Deleting session "ses-FNDM2" from subject sub-17155
# 2021-09-20 14:22:35,022 INFO Deleting session "ses-FNDM1" from subject sub-17158
# 2021-09-20 14:22:36,047 INFO Deleting session "ses-FNDM2" from subject sub-17158
# 2021-09-20 14:22:37,173 INFO Deleting session "ses-NEFF3" from subject sub-17158
# 2021-09-20 14:22:38,199 INFO Deleting session "ses-DAY1" from subject sub-17165
# 2021-09-20 14:22:39,324 INFO Deleting session "ses-FNDM2" from subject sub-17165
# 2021-09-20 14:22:40,447 INFO Deleting session "ses-NEFF3" from subject sub-17165
# 2021-09-20 14:22:41,576 INFO Deleting session "ses-FNDM1" from subject sub-17230
# 2021-09-20 14:22:42,703 INFO Deleting session "ses-FNDM2" from subject sub-17230
# 2021-09-20 14:22:43,830 INFO Deleting session "ses-NEFF3" from subject sub-17230
# 2021-09-20 14:22:44,752 INFO Deleting session "ses-FNDM1" from subject sub-17301
# 2021-09-20 14:22:45,570 INFO Deleting session "ses-FNDM2" from subject sub-17301
# 2021-09-20 14:22:46,627 INFO Deleting session "ses-FNDM1" from subject sub-17326
# 2021-09-20 14:22:47,774 INFO Deleting session "ses-FNDM2" from subject sub-17326
# 2021-09-20 14:22:48,596 INFO Deleting session "ses-FNDM1" from subject sub-17363
# 2021-09-20 14:22:49,385 INFO Deleting session "ses-FNDM2" from subject sub-17363
# 2021-09-20 14:22:50,224 INFO Deleting session "ses-FNDM1" from subject sub-17397
# 2021-09-20 14:22:51,202 INFO Deleting session "ses-FNDM2" from subject sub-17397
# 2021-09-20 14:22:52,123 INFO Deleting session "ses-FNDM1" from subject sub-17428
# 2021-09-20 14:22:53,251 INFO Deleting session "ses-FNDM2" from subject sub-17428
# 2021-09-20 14:22:54,377 INFO Deleting session "ses-FNDM1" from subject sub-17527
# 2021-09-20 14:22:55,299 INFO Deleting session "ses-FNDM2" from subject sub-17527
# 2021-09-20 14:22:56,320 INFO Deleting session "ses-FNDM1" from subject sub-17545
# 2021-09-20 14:22:57,346 INFO Deleting session "ses-FNDM2" from subject sub-17545
# 2021-09-20 14:22:58,369 INFO Deleting session "ses-FNDM1" from subject sub-17548
# 2021-09-20 14:22:59,395 INFO Deleting session "ses-FNDM2" from subject sub-17548
# 2021-09-20 14:23:00,521 INFO Deleting session "ses-FNDM1" from subject sub-17673
# 2021-09-20 14:23:01,546 INFO Deleting session "ses-FNDM2" from subject sub-17673
# 2021-09-20 14:23:02,772 INFO Deleting session "ses-DAY1" from subject sub-17688
# 2021-09-20 14:23:03,796 INFO Deleting session "ses-FNDM2" from subject sub-17688
# 2021-09-20 14:23:05,024 INFO Deleting session "ses-FNDM1" from subject sub-17734
# 2021-09-20 14:23:06,460 INFO Deleting session "ses-FNDM2" from subject sub-17734
# 2021-09-20 14:23:07,586 INFO Deleting session "ses-DAY1" from subject sub-17838
# 2021-09-20 14:23:08,704 INFO Deleting session "ses-FNDM2" from subject sub-17838
# 2021-09-20 14:23:09,777 INFO Deleting session "ses-FNDM1" from subject sub-17962
# 2021-09-20 14:23:10,885 INFO Deleting session "ses-FNDM2" from subject sub-17962
# 2021-09-20 14:23:11,786 INFO Deleting session "ses-FNDM1" from subject sub-18013
# 2021-09-20 14:23:12,705 INFO Deleting session "ses-FNDM2" from subject sub-18013
# 2021-09-20 14:23:13,627 INFO Deleting session "ses-PNC1" from subject sub-110689
# 2021-09-20 14:23:14,584 INFO Deleting session "ses-PNC2" from subject sub-110689

# %%
# 2. Remove empty subjects from Flywheel
check_for_empty = remove.bblid.unique()
for bblid in check_for_empty:
    sub = getSubject(bblid)
    if sub:
        delete_empty_subject(sub, dry_run=False)
# Out:
# Subject sub-10410 not found on Flywheel!
# 2021-09-20 14:24:12,096 INFO Checking if subject "sub-11186" is empty
# 2021-09-20 14:24:12,306 INFO Found 0 sessions
# 2021-09-20 14:24:12,337 INFO Deleting subject "sub-11186"
# 2021-09-20 14:24:12,916 INFO Checking if subject "sub-11242" is empty
# 2021-09-20 14:24:13,221 INFO Found 0 sessions
# 2021-09-20 14:24:13,222 INFO Deleting subject "sub-11242"
# 2021-09-20 14:24:13,751 INFO Checking if subject "sub-11399" is empty
# 2021-09-20 14:24:14,047 INFO Found 2 sessions
# 2021-09-20 14:24:14,218 INFO Checking if subject "sub-11419" is empty
# 2021-09-20 14:24:14,377 INFO Found 0 sessions
# 2021-09-20 14:24:14,382 INFO Deleting subject "sub-11419"
# 2021-09-20 14:24:14,864 INFO Checking if subject "sub-11569" is empty
# 2021-09-20 14:24:15,046 INFO Found 0 sessions
# 2021-09-20 14:24:15,048 INFO Deleting subject "sub-11569"
# 2021-09-20 14:24:15,558 INFO Checking if subject "sub-11599" is empty
# 2021-09-20 14:24:15,782 INFO Found 0 sessions
# 2021-09-20 14:24:15,783 INFO Deleting subject "sub-11599"
# 2021-09-20 14:24:16,295 INFO Checking if subject "sub-11762" is empty
# 2021-09-20 14:24:16,601 INFO Found 0 sessions
# 2021-09-20 14:24:16,601 INFO Deleting subject "sub-11762"
# 2021-09-20 14:24:17,321 INFO Checking if subject "sub-11866" is empty
# 2021-09-20 14:24:17,626 INFO Found 0 sessions
# 2021-09-20 14:24:17,628 INFO Deleting subject "sub-11866"
# 2021-09-20 14:24:18,240 INFO Checking if subject "sub-12285" is empty
# 2021-09-20 14:24:18,498 INFO Found 0 sessions
# 2021-09-20 14:24:18,499 INFO Deleting subject "sub-12285"
# 2021-09-20 14:24:19,162 INFO Checking if subject "sub-12498" is empty
# 2021-09-20 14:24:19,469 INFO Found 0 sessions
# 2021-09-20 14:24:19,470 INFO Deleting subject "sub-12498"
# 2021-09-20 14:24:20,289 INFO Checking if subject "sub-12583" is empty
# 2021-09-20 14:24:20,489 INFO Found 0 sessions
# 2021-09-20 14:24:20,490 INFO Deleting subject "sub-12583"
# 2021-09-20 14:24:21,211 INFO Checking if subject "sub-12738" is empty
# 2021-09-20 14:24:21,620 INFO Found 0 sessions
# 2021-09-20 14:24:21,621 INFO Deleting subject "sub-12738"
# 2021-09-20 14:24:22,440 INFO Checking if subject "sub-12740" is empty
# 2021-09-20 14:24:22,746 INFO Found 0 sessions
# 2021-09-20 14:24:22,747 INFO Deleting subject "sub-12740"
# 2021-09-20 14:24:23,260 INFO Checking if subject "sub-12822" is empty
# 2021-09-20 14:24:23,565 INFO Found 0 sessions
# 2021-09-20 14:24:23,567 INFO Deleting subject "sub-12822"
# 2021-09-20 14:24:24,385 INFO Checking if subject "sub-12938" is empty
# 2021-09-20 14:24:24,588 INFO Found 0 sessions
# 2021-09-20 14:24:24,589 INFO Deleting subject "sub-12938"
# 2021-09-20 14:24:25,202 INFO Checking if subject "sub-13372" is empty
# 2021-09-20 14:24:25,511 INFO Found 0 sessions
# 2021-09-20 14:24:25,512 INFO Deleting subject "sub-13372"
# 2021-09-20 14:24:26,125 INFO Checking if subject "sub-13394" is empty
# 2021-09-20 14:24:26,413 INFO Found 1 sessions
# 2021-09-20 14:24:26,629 INFO Checking if subject "sub-13548" is empty
# 2021-09-20 14:24:26,841 INFO Found 0 sessions
# 2021-09-20 14:24:26,841 INFO Deleting subject "sub-13548"
# 2021-09-20 14:24:27,661 INFO Checking if subject "sub-14805" is empty
# 2021-09-20 14:24:27,968 INFO Found 0 sessions
# 2021-09-20 14:24:27,969 INFO Deleting subject "sub-14805"
# 2021-09-20 14:24:28,685 INFO Checking if subject "sub-15311" is empty
# 2021-09-20 14:24:28,995 INFO Found 0 sessions
# 2021-09-20 14:24:28,996 INFO Deleting subject "sub-15311"
# 2021-09-20 14:24:29,813 INFO Checking if subject "sub-15426" is empty
# 2021-09-20 14:24:30,018 INFO Found 0 sessions
# 2021-09-20 14:24:30,020 INFO Deleting subject "sub-15426"
# 2021-09-20 14:24:30,737 INFO Checking if subject "sub-15428" is empty
# 2021-09-20 14:24:31,042 INFO Found 0 sessions
# 2021-09-20 14:24:31,043 INFO Deleting subject "sub-15428"
# 2021-09-20 14:24:31,860 INFO Checking if subject "sub-15444" is empty
# 2021-09-20 14:24:32,167 INFO Found 0 sessions
# 2021-09-20 14:24:32,168 INFO Deleting subject "sub-15444"
# 2021-09-20 14:24:32,883 INFO Checking if subject "sub-15628" is empty
# 2021-09-20 14:24:33,087 INFO Found 0 sessions
# 2021-09-20 14:24:33,088 INFO Deleting subject "sub-15628"
# 2021-09-20 14:24:33,806 INFO Checking if subject "sub-15630" is empty
# 2021-09-20 14:24:34,113 INFO Found 0 sessions
# 2021-09-20 14:24:34,114 INFO Deleting subject "sub-15630"
# 2021-09-20 14:24:34,932 INFO Checking if subject "sub-15688" is empty
# 2021-09-20 14:24:35,240 INFO Found 1 sessions
# 2021-09-20 14:24:35,445 INFO Checking if subject "sub-15802" is empty
# 2021-09-20 14:24:35,677 INFO Found 0 sessions
# 2021-09-20 14:24:35,678 INFO Deleting subject "sub-15802"
# 2021-09-20 14:24:36,469 INFO Checking if subject "sub-16206" is empty
# 2021-09-20 14:24:36,773 INFO Found 0 sessions
# 2021-09-20 14:24:36,774 INFO Deleting subject "sub-16206"
# 2021-09-20 14:24:37,389 INFO Checking if subject "sub-16234" is empty
# 2021-09-20 14:24:37,696 INFO Found 0 sessions
# 2021-09-20 14:24:37,697 INFO Deleting subject "sub-16234"
# 2021-09-20 14:24:38,211 INFO Checking if subject "sub-16239" is empty
# 2021-09-20 14:24:38,414 INFO Found 0 sessions
# 2021-09-20 14:24:38,415 INFO Deleting subject "sub-16239"
# 2021-09-20 14:24:39,029 INFO Checking if subject "sub-16336" is empty
# 2021-09-20 14:24:39,334 INFO Found 0 sessions
# 2021-09-20 14:24:39,335 INFO Deleting subject "sub-16336"
# 2021-09-20 14:24:40,256 INFO Checking if subject "sub-16382" is empty
# 2021-09-20 14:24:40,563 INFO Found 0 sessions
# 2021-09-20 14:24:40,564 INFO Deleting subject "sub-16382"
# 2021-09-20 14:24:41,282 INFO Checking if subject "sub-16492" is empty
# 2021-09-20 14:24:41,588 INFO Found 0 sessions
# 2021-09-20 14:24:41,589 INFO Deleting subject "sub-16492"
# 2021-09-20 14:24:42,319 INFO Checking if subject "sub-16603" is empty
# 2021-09-20 14:24:42,610 INFO Found 0 sessions
# 2021-09-20 14:24:42,611 INFO Deleting subject "sub-16603"
# 2021-09-20 14:24:43,225 INFO Checking if subject "sub-16661" is empty
# 2021-09-20 14:24:43,432 INFO Found 0 sessions
# 2021-09-20 14:24:43,433 INFO Deleting subject "sub-16661"
# 2021-09-20 14:24:44,148 INFO Checking if subject "sub-16662" is empty
# 2021-09-20 14:24:44,455 INFO Found 0 sessions
# 2021-09-20 14:24:44,456 INFO Deleting subject "sub-16662"
# 2021-09-20 14:24:45,070 INFO Checking if subject "sub-16668" is empty
# 2021-09-20 14:24:45,273 INFO Found 0 sessions
# 2021-09-20 14:24:45,274 INFO Deleting subject "sub-16668"
# 2021-09-20 14:24:45,889 INFO Checking if subject "sub-16717" is empty
# 2021-09-20 14:24:46,092 INFO Found 0 sessions
# 2021-09-20 14:24:46,093 INFO Deleting subject "sub-16717"
# 2021-09-20 14:24:46,620 INFO Checking if subject "sub-16809" is empty
# 2021-09-20 14:24:46,814 INFO Found 0 sessions
# 2021-09-20 14:24:46,814 INFO Deleting subject "sub-16809"
# 2021-09-20 14:24:47,340 INFO Checking if subject "sub-17028" is empty
# 2021-09-20 14:24:47,529 INFO Found 0 sessions
# 2021-09-20 14:24:47,530 INFO Deleting subject "sub-17028"
# 2021-09-20 14:24:48,469 INFO Checking if subject "sub-17096" is empty
# 2021-09-20 14:24:48,638 INFO Found 0 sessions
# 2021-09-20 14:24:48,639 INFO Deleting subject "sub-17096"
# 2021-09-20 14:24:49,273 INFO Checking if subject "sub-17108" is empty
# 2021-09-20 14:24:49,439 INFO Found 0 sessions
# 2021-09-20 14:24:49,440 INFO Deleting subject "sub-17108"
# 2021-09-20 14:24:50,079 INFO Checking if subject "sub-17155" is empty
# 2021-09-20 14:24:50,290 INFO Found 0 sessions
# 2021-09-20 14:24:50,291 INFO Deleting subject "sub-17155"
# 2021-09-20 14:24:50,907 INFO Checking if subject "sub-17158" is empty
# 2021-09-20 14:24:51,214 INFO Found 0 sessions
# 2021-09-20 14:24:51,215 INFO Deleting subject "sub-17158"
# 2021-09-20 14:24:52,036 INFO Checking if subject "sub-17165" is empty
# 2021-09-20 14:24:52,237 INFO Found 0 sessions
# 2021-09-20 14:24:52,238 INFO Deleting subject "sub-17165"
# 2021-09-20 14:24:52,852 INFO Checking if subject "sub-17230" is empty
# 2021-09-20 14:24:53,142 INFO Found 0 sessions
# 2021-09-20 14:24:53,143 INFO Deleting subject "sub-17230"
# 2021-09-20 14:24:53,672 INFO Checking if subject "sub-17301" is empty
# 2021-09-20 14:24:53,874 INFO Found 0 sessions
# 2021-09-20 14:24:53,875 INFO Deleting subject "sub-17301"
# 2021-09-20 14:24:54,490 INFO Checking if subject "sub-17326" is empty
# 2021-09-20 14:24:54,664 INFO Found 0 sessions
# 2021-09-20 14:24:54,665 INFO Deleting subject "sub-17326"
# 2021-09-20 14:24:55,308 INFO Checking if subject "sub-17363" is empty
# 2021-09-20 14:24:55,616 INFO Found 0 sessions
# 2021-09-20 14:24:55,618 INFO Deleting subject "sub-17363"
# 2021-09-20 14:24:56,175 INFO Checking if subject "sub-17397" is empty
# 2021-09-20 14:24:56,436 INFO Found 0 sessions
# 2021-09-20 14:24:56,437 INFO Deleting subject "sub-17397"
# 2021-09-20 14:24:57,153 INFO Checking if subject "sub-17428" is empty
# 2021-09-20 14:24:57,356 INFO Found 0 sessions
# 2021-09-20 14:24:57,358 INFO Deleting subject "sub-17428"
# 2021-09-20 14:24:57,968 INFO Checking if subject "sub-17527" is empty
# 2021-09-20 14:24:58,160 INFO Found 0 sessions
# 2021-09-20 14:24:58,161 INFO Deleting subject "sub-17527"
# 2021-09-20 14:24:58,743 INFO Checking if subject "sub-17545" is empty
# 2021-09-20 14:24:59,089 INFO Found 0 sessions
# 2021-09-20 14:24:59,090 INFO Deleting subject "sub-17545"
# 2021-09-20 14:24:59,806 INFO Checking if subject "sub-17548" is empty
# 2021-09-20 14:25:00,028 INFO Found 0 sessions
# 2021-09-20 14:25:00,029 INFO Deleting subject "sub-17548"
# 2021-09-20 14:25:00,858 INFO Checking if subject "sub-17673" is empty
# 2021-09-20 14:25:01,228 INFO Found 0 sessions
# 2021-09-20 14:25:01,230 INFO Deleting subject "sub-17673"
# 2021-09-20 14:25:01,759 INFO Checking if subject "sub-17688" is empty
# 2021-09-20 14:25:02,067 INFO Found 0 sessions
# 2021-09-20 14:25:02,068 INFO Deleting subject "sub-17688"
# 2021-09-20 14:25:02,787 INFO Checking if subject "sub-17734" is empty
# 2021-09-20 14:25:02,989 INFO Found 0 sessions
# 2021-09-20 14:25:02,991 INFO Deleting subject "sub-17734"
# 2021-09-20 14:25:03,502 INFO Checking if subject "sub-17838" is empty
# 2021-09-20 14:25:03,651 INFO Found 0 sessions
# 2021-09-20 14:25:03,652 INFO Deleting subject "sub-17838"
# 2021-09-20 14:25:04,219 INFO Checking if subject "sub-17962" is empty
# 2021-09-20 14:25:04,415 INFO Found 0 sessions
# 2021-09-20 14:25:04,416 INFO Deleting subject "sub-17962"
# 2021-09-20 14:25:04,837 INFO Checking if subject "sub-18013" is empty
# 2021-09-20 14:25:05,139 INFO Found 0 sessions
# 2021-09-20 14:25:05,140 INFO Deleting subject "sub-18013"
# 2021-09-20 14:25:05,754 INFO Checking if subject "sub-110689" is empty
# 2021-09-20 14:25:05,931 INFO Found 0 sessions
# 2021-09-20 14:25:05,932 INFO Deleting subject "sub-110689"

# %% [markdown]
# # Save new ExtraLong csv of scans we're keeping

# %%
xl = keep_filtered
xl.sort_values(by=['bblid','doscan'],inplace=True)
fname = f"./csv/ExtraLong-Datafreeze-2021-Updated-20210920.csv"
xl.to_csv(fname, index=False)
