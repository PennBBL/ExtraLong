# %% [markdown]
# # Querying Flywheel for the June 30th, 2021 Datafreeze
# **Project:** ExtraLong <br>
# **Author:** Katja Zoner <br>
# **Date:** 07/30/2021 <br>

# %% [markdown]
# # Step 0: Setup

# %%
import os
import sys
import logging
import numpy as np
import pandas as pd
import flywheel

# %% [markdown]
# # Step 1: Read in superset csv, convert to dataframe, and clean.

# %%
# Read superset csv.
csv = "./csv/all_long_scans_oracle_cleaned.csv"
superset = pd.read_csv(csv)

# Convert date of scan to timestamp dtype
superset["doscan"] = pd.to_datetime(superset["doscan"])
superset
# Out:
#       scanid   bblid           scan_protocol     doscan  timepoint  \
# 0        613   11660         700205 - Worden 2003-05-23          1
# 1        615   11518         700205 - Worden 2003-05-27          1
# 2        597   11382         700205 - Worden 2003-07-17          1
# 3        598   11565         700205 - Worden 2003-07-24          1
# 4        599   11530         700205 - Worden 2003-07-29          1
# ...      ...     ...                     ...        ...        ...
# 4252   11820   82039        833922 - EvolPsy 2021-07-12          5
# 4253   11803  132782  842909 - TRANSCENDS_D1 2021-07-12          3
# 4254   11804  132782  842909 - TRANSCENDS_D1 2021-07-19          4
# 4255   11805  132782  842909 - TRANSCENDS_D1 2021-07-30          5
# 4256   11806  132782  842909 - TRANSCENDS_D1 2021-08-09          6
#
#       ntimepoints  scanage_months  sex  race  ethnic scanstat
# 0               6          1240.0  NaN   NaN     NaN       C2
# 1               2           356.0  2.0   2.0     NaN       C2
# 2               4           260.0  2.0   2.0     2.0       C2
# 3               7           291.0  1.0   1.0     2.0       I7
# 4               4           331.0  1.0   2.0     2.0       C2
# ...           ...             ...  ...   ...     ...      ...
# 4252            5           367.0  2.0   2.0     2.0      NaN
# 4253            6           307.0  1.0   1.0     2.0      NaN
# 4254            6           307.0  1.0   1.0     2.0      NaN
# 4255            6           307.0  1.0   1.0     2.0      NaN
# 4256            6           307.0  1.0   1.0     2.0      IS9
#
# [4257 rows x 11 columns]

# %% [markdown]
# # Step 2: Get list of scan protocols to include in 2021 data freeze.

# %%
# Read superset csv.
csv = "./csv/protocols_for_inclusion.csv"
inclusion_df = pd.read_csv(csv)

inclusion_df.include.fillna(True,inplace=True)
protocols = list(inclusion_df.scan_protocol[inclusion_df.include == True])
protocols
# Out:
# ['808689 - AGGY',
#  '808922 - MGI2_PENN',
#  '808799 - DAY2',
#  '807360 - Olf Lifespan',
#  '810336 - Big GO',
#  '810336 - Go2 Supplement',
#  '810211 - FNDM',
#  'B10218 - MGI2_PITT',
#  '817628 - EFDO',
#  '816281 - NODRA',
#  '810336 - GO3 FOLLOW UP',
#  '810336 - Go3',
#  '816275 - ONM',
#  '815814 - Conte',
#  '822937 - HARMONY',
#  '818028 - Effort',
#  '818621 - SYRP',
#  '820690 - phASL',
#  '825940 - GluCEST in Psychosis',
#  '822831 - GRMPY',
#  '825834 - satterttPiloting',
#  '829502 - MOTIVE',
#  '834246 - 22qmidline',
#  '833922 - EvolPsy']

# %% [markdown]
# # Step 3: Generate csv of scans to include in ExtraLong 2021 Data Freeze

# %%
def filterBySessionCount(df, thresh):

    # Get scan counts for each subject (bblid).
    bblid_counts = df.groupby(["bblid"]).size().reset_index()
    bblid_counts.columns = ["bblid", "scan_count"]
    bblid_counts.sort_values("scan_count")

    # Get list of bblids that should be included
    include_bblids = bblid_counts.bblid[bblid_counts["scan_count"]>=thresh]

    # Filter dataframe to only include subjects that meet session requirements
    df = df[df["bblid"].isin(include_bblids)].copy()

    # Update ntimepoints column to indicate number of sessions in ExtraLong 2021 for each subject.
    for bblid in df.bblid.unique():

        # Get subject's number of timepoints in ExtraLong 2021
        num_tps = bblid_counts[bblid_counts.bblid == bblid].scan_count.item()

        # Update ntimeponts in ExtraLong dataframe
        df.loc[df.bblid==bblid, 'ntimepoints'] = num_tps

    # Update timepoint column to indicate timepoint number for each subject
    df["timepoint"] = df.groupby("bblid").cumcount()+1

    return df.sort_values(["bblid","doscan"])

# %%
# 1. Filter by superset by protocol (only include scan_protocols from inclusion csv)
df = superset[superset["scan_protocol"].isin(protocols)]

# 2. Filter by data freeze cutoff date
cutoff_date = pd.to_datetime("2021-07-01")
df = df[df.doscan < cutoff_date]

# 3. Filter by subject's session count (only include subjects with 2+ scans).
df = filterBySessionCount(df,2)
df
# Out:
#       scanid   bblid                  scan_protocol     doscan  timepoint  \
# 1059    3931   10180                  808799 - DAY2 2010-10-11          1
# 1172    4451   10180          807360 - Olf Lifespan 2011-01-31          2
# 1818    6776   10410                  810211 - FNDM 2012-04-24          1
# 1846    6843   10410                  810211 - FNDM 2012-05-11          2
# 1112    4185   11176                  808799 - DAY2 2010-11-23          1
# ...      ...     ...                            ...        ...        ...
# 3734   10739  139272  825940 - GluCEST in Psychosis 2018-03-29          8
# 2474    8461  139490                810336 - Big GO 2013-08-30          1
# 3601   10564  139490                 815814 - Conte 2017-04-29          2
# 2464    8410  139553                810336 - Big GO 2013-08-23          1
# 3109    9822  139553                   810336 - Go3 2015-09-12          2
#
#       ntimepoints  scanage_months  sex  race  ethnic scanstat
# 1059            2           566.0  1.0   2.0     2.0      IS4
# 1172            2           569.0  1.0   2.0     2.0      IS1
# 1818            2           556.0  2.0   2.0     2.0      IS1
# 1846            2           557.0  2.0   2.0     2.0      IS1
# 1112            2           337.0  1.0   1.0     2.0      IS1
# ...           ...             ...  ...   ...     ...      ...
# 3734            8           282.0  2.0   2.0     2.0      IS4
# 2474            2           105.0  1.0   2.0     2.0      IS2
# 3601            2           149.0  1.0   2.0     2.0      IS4
# 2464            2           107.0  2.0   2.0     2.0      IS2
# 3109            2           132.0  2.0   2.0     2.0      IS1
#
# [3112 rows x 11 columns]

# %% [markdown]
# # Step 4: Add in information for scans previously in ExtraLong 2019

# %%
# Read in ExtraLong sesid - scanid mapping csv
mapping_csv = "./csv/scanid_to_seslabel_10-16-2019.csv"
mapping = pd.read_csv(mapping_csv)

# Rename seslabel col to sesid
mapping.columns = ["project", "bblid", "scanid", "sesid"]
mapping = mapping[["bblid", "scanid", "sesid", "project"]]

# Cast col datatypes
mapping[["bblid", "scanid"]]=mapping[["bblid", "scanid"]].astype("int64")

# %%
xl = df.copy()
del xl["scanstat"]
xl["acqid"] = ""
xl["filename"] = ""

# Merge scanid-sesid mapping with xl dataframe to add in ExtraLong sesid's
xl = xl.merge(mapping, on=['scanid','bblid'], how='left')

# Reorder columns
xl = xl[['bblid','scanid','sesid','scan_protocol','project', 'filename', 'acqid', 'doscan', 'timepoint', 'ntimepoints', 'scanage_months', 'sex', 'race', 'ethnic']]
xl.sort_values(by=['project'])
# Out:
#        bblid  scanid  sesid                  scan_protocol      project  \
# 288    16098    5049  AGGY2                  808689 - AGGY  AGGY_808689
# 2294  111873    4109  AGGY1                  808689 - AGGY  AGGY_808689
# 239    15701    4325  AGGY2                  808689 - AGGY  AGGY_808689
# 238    15701    3694  AGGY1                  808689 - AGGY  AGGY_808689
# 2722  122124    2917  AGGY1                  808689 - AGGY  AGGY_808689
# ...      ...     ...    ...                            ...          ...
# 3093  135085   11650    NaN            834246 - 22qmidline          NaN
# 3098  139181    8470    NaN                810336 - Big GO          NaN
# 3099  139181   11619    NaN               833922 - EvolPsy          NaN
# 3104  139272    8985    NaN                   816275 - ONM          NaN
# 3107  139272   10739    NaN  825940 - GluCEST in Psychosis          NaN
#
#      filename acqid     doscan  timepoint  ntimepoints  scanage_months  sex  \
# 288                 2011-05-19          2            2           160.0  2.0
# 2294                2010-11-12          1            2           151.0  1.0
# 239                 2011-01-04          2            2           137.0  1.0
# 238                 2010-08-17          1            2           132.0  1.0
# 2722                2010-02-24          1            2           137.0  2.0
# ...       ...   ...        ...        ...          ...             ...  ...
# 3093                2021-02-11          3            3           222.0  2.0
# 3098                2013-08-31          1            2           162.0  2.0
# 3099                2021-01-11          2            2           250.0  2.0
# 3104                2014-07-22          5            8           238.0  2.0
# 3107                2018-03-29          8            8           282.0  2.0
#
#       race  ethnic
# 288    2.0     NaN
# 2294   2.0     2.0
# 239    2.0     NaN
# 238    2.0     NaN
# 2722   2.0     2.0
# ...    ...     ...
# 3093   1.0     2.0
# 3098   2.0     NaN
# 3099   2.0     NaN
# 3104   2.0     2.0
# 3107   2.0     2.0
#
# [3112 rows x 14 columns]

# %%
# Get earliest timestamp in previous ExtraLong freeze to use as timestamp threshold for new datafreeze
old = xl[xl.project.notnull()].copy()
earliest = old.min().doscan
print(earliest)
old.sort_values('doscan')
# Out:
# 2009-10-28 00:00:00
#        bblid  scanid    sesid    scan_protocol        project filename acqid  \
# 2133  130896    2542    AGGY1    808689 - AGGY    AGGY_808689
# 177    80812    2646     PNC1  810336 - Big GO  PNC_CS_810336
# 179    80854    2675     PNC1  810336 - Big GO  PNC_CS_810336
# 241    82232    2706     PNC1  810336 - Big GO  PNC_CS_810336
# 216    81982    2723     PNC1  810336 - Big GO  PNC_CS_810336
# ...      ...     ...      ...              ...            ...      ...   ...
# 1079   98535   11254    11254   822831 - GRMPY   GRMPY_822831
# 1611  114723   11256    11256   822831 - GRMPY   GRMPY_822831
# 1998  126921   11262    11262   822831 - GRMPY   GRMPY_822831
# 1530  112200   11349  motive1  829502 - MOTIVE         MOTIVE
# 413    86350   11398  motive1  829502 - MOTIVE         MOTIVE
#
#          doscan  timepoint  ntimepoints  scanage_months  sex  race  ethnic
# 2133 2009-10-28          1            6           144.0  2.0   2.0     2.0
# 177  2009-12-05          1            2           247.0  2.0   2.0     2.0
# 179  2009-12-17          1            2           242.0  1.0   1.0     2.0
# 241  2010-01-07          1            2           228.0  2.0   1.0     2.0
# 216  2010-01-09          1            2           231.0  2.0   1.0     2.0
# ...         ...        ...          ...             ...  ...   ...     ...
# 1079 2019-05-07          3            4           221.0  1.0   1.0     1.0
# 1611 2019-05-09          2            2           328.0  1.0   2.0     2.0
# 1998 2019-05-15          2            3           226.0  1.0   2.0     2.0
# 1530 2019-08-07          6            7           261.0  1.0   1.0     2.0
# 413  2019-10-02          3            3           304.0  2.0   2.0     2.0
#
# [1942 rows x 14 columns]

# %% [markdown]
# # Step 5: Locating Scans on Flywheel

# %%
#PROJECT_LABEL = "ExtraLong"

IS_BIDSIFIED = [
    "ExtraLong",
    "AGGY_808689", 
    "CONTE_815814", 
    "GRMPY_822831", 
    "MOTIVE",
    "SYRP_818621", 
    "NEFF_818028",
    "PNC_CS_810336"
]

DEPRECATED_PROJECTS = [
    "DAY2_808799",
    "FNDM1_810211",
    "FNDM2_810211",
    "NODRA_816281",
    "ONM_816275"
]

DEPRECATED_PROTOCOLS = [
    "808799 - DAY2",
    "810211 - FNDM",
    "816281 - NODRA",
    "816275 - ONM",
    "807360 - Olf Lifespan",
    '808922 - MGI2_PENN',
    '820690 - phASL',
    "825834 - satterttPiloting",
    "822937 - HARMONY",
    "817628 - EFDO",
    "825940 - GluCEST in Psychosis"
]

# Get client
fw = flywheel.Client()
assert fw, "Your Flywheel CLI credentials aren't set!"

# Get project object
# xlProject = fw.projects.find_first('label="{}"'.format(PROJECT_LABEL))
# assert xlProject, "Project not found!"

# %%
def hasBIDS(f):
    '''
    Helper function to check if file has bids metadata.
    '''
    try:
        #return f.info['BIDS']['Modality'] == 'T1w'
        return f.info['BIDS']['Filename'].split('_')[-1] == 'T1w.nii.gz'
    except:
        return False

# %%
# Functions below are heuristics to identify valid T1w images across all projects in ExtraLong.
def find_from_bids(acq):
    return [f.name for f in acq.files if hasBIDS(f) and f.size > MIN_SIZE]
    
def find_from_old_xl(acq):
    return [f.name for f in acq.files if f.type =='nifti' and f.size > MIN_SIZE]

def find_by_mprage_in_fname(acq):
    return [f.name for f in acq.files if f.type == 'nifti' and 'mprage' in f.name.lower() and f.size > MIN_SIZE]

def find_by_other_fname(acq):
    return [f.name for f in acq.files if f.type == 'nifti' and 't1w_mpr_vnav_4' in f.name.lower() and f.size > MIN_SIZE]

def find_by_acq_label(acq):
    valid_acq_labels = [
            'ABCD_T1w_MPR_vNav',
            'anat-T1w_acq-vNavBC_seq-ABCD__MPRAGE'
    ]
    
    if acq.label in valid_acq_labels:
            return [f.name for f in acq.files if f.type == 'nifti' and f.size > MIN_SIZE]
    else:
            return []

MIN_SIZE = 6000000
# List of heuristic functions to try to identify T1w image in acquisition
HEURISTICS = [
    #find_from_bids,
    #find_from_old_xl,
    find_by_mprage_in_fname,
    find_by_acq_label,
    find_by_other_fname
]

# %%
def find_t1w_in_results(results):
    all_files = []
    t1w_info = []

    # Get project label
    if len(results) > 0:
        project = results[0].project.label

    # Loop through all acquisitions found by query
    for res in results:
        # Get acquisition object
        acqid = res.acquisition.id
        acq = fw.get_acquisition(acqid)

        # Add to list of all files in session
        all_files.extend([f.name for f in acq.files if f.type == 'nifti'])

        # Try BIDS heuristic first --> if found ignore other results and return BIDS T1w image
        files = find_from_bids(acq)
        if len(files) == 1:
            return project, acqid, files[0]

        # Try searching for T1w image using each heuristic. 
        # Break if T1w image is identified.
        for heuristic_func in HEURISTICS:

            # Only apply the old xl heuristic if acq was from ExtraLong
            #if heuristic_func == find_from_old_xl and project != 'ExtraLong':
            #    continue
            
            # Apply heuristic to look for matching files
            files = heuristic_func(acq)
            
            # If any matching files were found, add fname and acq id to info list and break.
            if len(files) > 0:
                #useCounts[heuristic_func] +=1
                for fname in files:
                    t1w_info.append( (project, acqid, fname) )
                break

    # If a single T1w image was found, return the image info.
    if len(t1w_info) == 1:
        # Returns tuple of (project, acqid, filename)
        return t1w_info[0]

    if len(t1w_info) > 1:
        print(f'Warning: Multiple T1w images found for session: {res.session.label}!')
        return (project, None, "multiple")
            
    # If no T1w image was found in any acquisition after trying all heuristics, print all filenames.
    print(f'Warning: No T1w image found for session: {results[0].session.label}!')
    print(all_files)

# %%
def query_flywheel_for_acqs(scan):
    results = None

    # If scan already has project label, search in ExtraLong project.
    if not pd.isnull(scan.project):
        query = f'project.label == ExtraLong AND ' \
                f'subject.label == sub-{scan.bblid} AND ' \
                f'session.label == ses-{scan.sesid} '
        results = fw.search({'structured_query': query, 'return_type': 'acquisition'}, size=100)


    # Else if scan wasn't part of old ExtraLong, query all Flywheel.
    if not results:
        query = f'session.label == {scan.scanid} AND ' \
                f'subject.label == {scan.bblid} '
        results = fw.search({'structured_query': query, 'return_type': 'acquisition'}, size=100)

    return results

# %%
################## Loop through XL dataframe and attempt to locate each T1w image on Flywheel. ##################

# Initialize a dataframe with same column labels to hold scans that couldn't be found.
failed = pd.DataFrame(columns=xl.columns)

useCounts = dict()
for h in HEURISTICS:
    useCounts[h] = 0

# Search Flywheel for each scan in dataframe.
for index, scan in xl[xl.acqid == ""].iterrows():
    
    # # Skip scans that we know aren't there
    # if scan.scan_protocol in DEPRECATED_PROTOCOLS:
    #     continue

    # Get list of acquisitions matching bblid/sesid/scanid 
    results = query_flywheel_for_acqs(scan)
    
    # If no result are found
    if results is None or len(results) == 0:
        print(f"Warning: scanid {scan.scanid} not found on Flywheel.")
        failed = failed.append(scan)
        continue

    # Get project label, acquisition id, and filename for acq with correct T1w image.
    t1w_info = find_t1w_in_results(results)
    
    # If T1w image could not be found on Flywheel, add to failed dataframe
    if t1w_info is None:
        #print(f"No T1w image found for scanid: {scan.scanid}.")
        failed = failed.append(scan)

    # If project located but no T1w found, add to failed dataframe
    elif t1w_info[1] is None:
        #print(f"No T1w image found for scanid: {scan.scanid}.")
        scan.project = t1w_info[0]
        failed = failed.append(scan)
        xl.loc[index, "project"] = t1w_info[0]      # Project label
        if t1w_info[2] is not None:
            xl.loc[index, "filename"] = t1w_info[2]     # T1w filename
        
    else:
        print(t1w_info)
        xl.loc[index, "project"] = t1w_info[0]      # Project label
        xl.loc[index, "acqid"] = t1w_info[1]        # Acquisition id
        xl.loc[index, "filename"] = t1w_info[2]     # T1w filename
# Out:
# Warning: scanid 3931 not found on Flywheel.
# Warning: scanid 4451 not found on Flywheel.
# Warning: scanid 4185 not found on Flywheel.
# Warning: scanid 4785 not found on Flywheel.
# Warning: scanid 3197 not found on Flywheel.
# Warning: scanid 3195 not found on Flywheel.
# Warning: scanid 3477 not found on Flywheel.
# Warning: scanid 4782 not found on Flywheel.
# Warning: scanid 5827 not found on Flywheel.
# Warning: scanid 2457 not found on Flywheel.
# Warning: scanid 4585 not found on Flywheel.
# Warning: scanid 2386 not found on Flywheel.
# Warning: scanid 2608 not found on Flywheel.
# Warning: scanid 6922 not found on Flywheel.
# Warning: scanid 8188 not found on Flywheel.
# Warning: scanid 4404 not found on Flywheel.
# Warning: scanid 2535 not found on Flywheel.
# Warning: scanid 4171 not found on Flywheel.
# Warning: scanid 5114 not found on Flywheel.
# Warning: scanid 2336 not found on Flywheel.
# Warning: scanid 2931 not found on Flywheel.
# Warning: scanid 2958 not found on Flywheel.
# Warning: scanid 4530 not found on Flywheel.
# Warning: scanid 2814 not found on Flywheel.
# Warning: scanid 3590 not found on Flywheel.
# Warning: scanid 5291 not found on Flywheel.
# Warning: scanid 3134 not found on Flywheel.
# Warning: scanid 3182 not found on Flywheel.
# Warning: scanid 2052 not found on Flywheel.
# Warning: scanid 5832 not found on Flywheel.
# Warning: scanid 5787 not found on Flywheel.
# Warning: scanid 3221 not found on Flywheel.
# Warning: scanid 6768 not found on Flywheel.
# Warning: scanid 5080 not found on Flywheel.
# Warning: scanid 4149 not found on Flywheel.
# Warning: scanid 4752 not found on Flywheel.
# Warning: scanid 8604 not found on Flywheel.
# Warning: scanid 8899 not found on Flywheel.
# Warning: scanid 3843 not found on Flywheel.
# Warning: scanid 4568 not found on Flywheel.
# Warning: scanid 2278 not found on Flywheel.
# Warning: scanid 2463 not found on Flywheel.
# Warning: scanid 2959 not found on Flywheel.
# Warning: scanid 2143 not found on Flywheel.
# Warning: scanid 2957 not found on Flywheel.
# Warning: scanid 3073 not found on Flywheel.
# Warning: scanid 2707 not found on Flywheel.
# Warning: scanid 3766 not found on Flywheel.
# Warning: scanid 10286 not found on Flywheel.
# Warning: scanid 10285 not found on Flywheel.
# Warning: scanid 10298 not found on Flywheel.
# Warning: scanid 10297 not found on Flywheel.
# Warning: scanid 2897 not found on Flywheel.
# Warning: scanid 2530 not found on Flywheel.
# Warning: scanid 5661 not found on Flywheel.
# Warning: scanid 6753 not found on Flywheel.
# Warning: scanid 7339 not found on Flywheel.
# Warning: scanid 2737 not found on Flywheel.
# Warning: scanid 5099 not found on Flywheel.
# Warning: scanid 3028 not found on Flywheel.
# Warning: scanid 5460 not found on Flywheel.
# Warning: scanid 2544 not found on Flywheel.
# Warning: scanid 5113 not found on Flywheel.
# Warning: scanid 2124 not found on Flywheel.
# Warning: scanid 2602 not found on Flywheel.
# Warning: scanid 5369 not found on Flywheel.
# Warning: scanid 3587 not found on Flywheel.
# Warning: scanid 10399 not found on Flywheel.
# Warning: scanid 10398 not found on Flywheel.
# Warning: scanid 10401 not found on Flywheel.
# Warning: scanid 10400 not found on Flywheel.
# Warning: scanid 2276 not found on Flywheel.
# Warning: scanid 2269 not found on Flywheel.
# Warning: scanid 5771 not found on Flywheel.
# Warning: scanid 3786 not found on Flywheel.
# Warning: scanid 4920 not found on Flywheel.
# Warning: scanid 6440 not found on Flywheel.
# Warning: scanid 2171 not found on Flywheel.
# Warning: scanid 2346 not found on Flywheel.
# Warning: scanid 2172 not found on Flywheel.
# Warning: scanid 2219 not found on Flywheel.
# Warning: scanid 2573 not found on Flywheel.
# Warning: scanid 3585 not found on Flywheel.
# Warning: scanid 3644 not found on Flywheel.
# Warning: scanid 4204 not found on Flywheel.
# Warning: scanid 2532 not found on Flywheel.
# Warning: scanid 4969 not found on Flywheel.
# Warning: scanid 7300 not found on Flywheel.
# Warning: scanid 2461 not found on Flywheel.
# Warning: scanid 2511 not found on Flywheel.
# Warning: scanid 2627 not found on Flywheel.
# Warning: scanid 4297 not found on Flywheel.
# Warning: scanid 4420 not found on Flywheel.
# Warning: scanid 3143 not found on Flywheel.
# Warning: scanid 4700 not found on Flywheel.
# Warning: scanid 5727 not found on Flywheel.
# Warning: scanid 6856 not found on Flywheel.
# Warning: scanid 5725 not found on Flywheel.
# Warning: scanid 8752 not found on Flywheel.
# Warning: scanid 10284 not found on Flywheel.
# Warning: scanid 9981 not found on Flywheel.
# Warning: scanid 4918 not found on Flywheel.
# Warning: scanid 3331 not found on Flywheel.
# Warning: scanid 9690 not found on Flywheel.
# Warning: scanid 3908 not found on Flywheel.
# Warning: scanid 4926 not found on Flywheel.
# Warning: scanid 9009 not found on Flywheel.
# Warning: scanid 3723 not found on Flywheel.
# Warning: scanid 4977 not found on Flywheel.
# Warning: scanid 5262 not found on Flywheel.
# Warning: scanid 5339 not found on Flywheel.
# Warning: scanid 7564 not found on Flywheel.
# Warning: scanid 10364 not found on Flywheel.
# Warning: scanid 10365 not found on Flywheel.
# Warning: scanid 10375 not found on Flywheel.
# Warning: scanid 10374 not found on Flywheel.
# Warning: scanid 5359 not found on Flywheel.
# Warning: scanid 7020 not found on Flywheel.
# Warning: scanid 7616 not found on Flywheel.
# Warning: scanid 5958 not found on Flywheel.
# Warning: scanid 3810 not found on Flywheel.
# Warning: scanid 4333 not found on Flywheel.
# Warning: scanid 6758 not found on Flywheel.
# Warning: scanid 3929 not found on Flywheel.
# Warning: scanid 10817 not found on Flywheel.
# Warning: scanid 10818 not found on Flywheel.
# Warning: scanid 10825 not found on Flywheel.
# Warning: scanid 10824 not found on Flywheel.
# Warning: scanid 11341 not found on Flywheel.
# Warning: scanid 7644 not found on Flywheel.
# Warning: scanid 7667 not found on Flywheel.
# Warning: scanid 5533 not found on Flywheel.
# Warning: scanid 6443 not found on Flywheel.
# Warning: scanid 4552 not found on Flywheel.
# Warning: scanid 5710 not found on Flywheel.
# Warning: scanid 7565 not found on Flywheel.
# Warning: scanid 6777 not found on Flywheel.
# Warning: scanid 4699 not found on Flywheel.
# Warning: scanid 7384 not found on Flywheel.
# Warning: scanid 7488 not found on Flywheel.
# Warning: scanid 5317 not found on Flywheel.
# Warning: scanid 5488 not found on Flywheel.
# Warning: scanid 6871 not found on Flywheel.
# Warning: scanid 5201 not found on Flywheel.
# Warning: scanid 6862 not found on Flywheel.
# Warning: scanid 5937 not found on Flywheel.
# Warning: scanid 5093 not found on Flywheel.
# Warning: scanid 7301 not found on Flywheel.
# Warning: scanid 9184 not found on Flywheel.
# Warning: scanid 10281 not found on Flywheel.
# Warning: scanid 5164 not found on Flywheel.
# Warning: scanid 7253 not found on Flywheel.
# Warning: scanid 5577 not found on Flywheel.
# Warning: scanid 5921 not found on Flywheel.
# Warning: scanid 5833 not found on Flywheel.
# Warning: scanid 5784 not found on Flywheel.
# Warning: scanid 9205 not found on Flywheel.
# Warning: scanid 6831 not found on Flywheel.
# Warning: scanid 5817 not found on Flywheel.
# Warning: scanid 6301 not found on Flywheel.
# Warning: scanid 7035 not found on Flywheel.
# Warning: scanid 9760 not found on Flywheel.
# Warning: scanid 7380 not found on Flywheel.
# Warning: scanid 6992 not found on Flywheel.
# Warning: scanid 8560 not found on Flywheel.
# Warning: scanid 8944 not found on Flywheel.
# Warning: scanid 6781 not found on Flywheel.
# Warning: scanid 7310 not found on Flywheel.
# Warning: scanid 8124 not found on Flywheel.
# Warning: scanid 9334 not found on Flywheel.
# Warning: scanid 9331 not found on Flywheel.
# Warning: scanid 8554 not found on Flywheel.
# Warning: scanid 8785 not found on Flywheel.
# Warning: scanid 10598 not found on Flywheel.
# Warning: scanid 10599 not found on Flywheel.
# Warning: scanid 10602 not found on Flywheel.
# Warning: scanid 10601 not found on Flywheel.
# Warning: scanid 7949 not found on Flywheel.
# Warning: scanid 8962 not found on Flywheel.
# Warning: scanid 8559 not found on Flywheel.
# Warning: scanid 8576 not found on Flywheel.
# Warning: scanid 8941 not found on Flywheel.
# Warning: scanid 9064 not found on Flywheel.
# Warning: scanid 8943 not found on Flywheel.
# Warning: scanid 8575 not found on Flywheel.
# Warning: scanid 8836 not found on Flywheel.
# Warning: scanid 7785 not found on Flywheel.
# Warning: scanid 8942 not found on Flywheel.
# Warning: scanid 9464 not found on Flywheel.
# Warning: scanid 8440 not found on Flywheel.
# Warning: scanid 8869 not found on Flywheel.
# Warning: scanid 8585 not found on Flywheel.
# Warning: scanid 8893 not found on Flywheel.
# Warning: scanid 8924 not found on Flywheel.
# Warning: scanid 8724 not found on Flywheel.
# Warning: scanid 8802 not found on Flywheel.
# Warning: scanid 9577 not found on Flywheel.
# Warning: scanid 8823 not found on Flywheel.
# Warning: scanid 8824 not found on Flywheel.
# Warning: scanid 8829 not found on Flywheel.
# Warning: scanid 8828 not found on Flywheel.
# Warning: scanid 8827 not found on Flywheel.
# Warning: scanid 9183 not found on Flywheel.
# Warning: scanid 9269 not found on Flywheel.
# Warning: scanid 8905 not found on Flywheel.
# Warning: scanid 8904 not found on Flywheel.
# Warning: scanid 9012 not found on Flywheel.
# Warning: scanid 9109 not found on Flywheel.
# Warning: scanid 9032 not found on Flywheel.
# Warning: scanid 9014 not found on Flywheel.
# Warning: scanid 9015 not found on Flywheel.
# Warning: scanid 9095 not found on Flywheel.
# Warning: scanid 9133 not found on Flywheel.
# Warning: scanid 9118 not found on Flywheel.
# Warning: scanid 9131 not found on Flywheel.
# Warning: scanid 9424 not found on Flywheel.
# Warning: scanid 9578 not found on Flywheel.
# Warning: scanid 9443 not found on Flywheel.
# Warning: scanid 9458 not found on Flywheel.
# Warning: scanid 10266 not found on Flywheel.
# Warning: scanid 10265 not found on Flywheel.
# Warning: scanid 10274 not found on Flywheel.
# Warning: scanid 10273 not found on Flywheel.
# Warning: scanid 10091 not found on Flywheel.
# Warning: scanid 10425 not found on Flywheel.
# Warning: scanid 10424 not found on Flywheel.
# Warning: scanid 10526 not found on Flywheel.
# Warning: scanid 10525 not found on Flywheel.
# Warning: scanid 10531 not found on Flywheel.
# Warning: scanid 10530 not found on Flywheel.
# Warning: scanid 9927 not found on Flywheel.
# Warning: scanid 10085 not found on Flywheel.
# Warning: scanid 10253 not found on Flywheel.
# Warning: scanid 10406 not found on Flywheel.
# Warning: scanid 10317 not found on Flywheel.
# Warning: scanid 10347 not found on Flywheel.
# Warning: scanid 10328 not found on Flywheel.
# Warning: scanid 10327 not found on Flywheel.
# Warning: scanid 10336 not found on Flywheel.
# Warning: scanid 10337 not found on Flywheel.
# Warning: scanid 10349 not found on Flywheel.
# Warning: scanid 10348 not found on Flywheel.
# Warning: scanid 10354 not found on Flywheel.
# Warning: scanid 10353 not found on Flywheel.
# Warning: scanid 10703 not found on Flywheel.
# Warning: scanid 10733 not found on Flywheel.
# Warning: scanid 10311 not found on Flywheel.
# Warning: scanid 10312 not found on Flywheel.
# Warning: scanid 10320 not found on Flywheel.
# Warning: scanid 10321 not found on Flywheel.
# Warning: scanid 10359 not found on Flywheel.
# Warning: scanid 10358 not found on Flywheel.
# Warning: scanid 10372 not found on Flywheel.
# Warning: scanid 10373 not found on Flywheel.
# Warning: scanid 10378 not found on Flywheel.
# Warning: scanid 10377 not found on Flywheel.
# Warning: scanid 10389 not found on Flywheel.
# Warning: scanid 10390 not found on Flywheel.
# Warning: scanid 10395 not found on Flywheel.
# Warning: scanid 10413 not found on Flywheel.
# Warning: scanid 10449 not found on Flywheel.
# Warning: scanid 10448 not found on Flywheel.
# Warning: scanid 10465 not found on Flywheel.
# Warning: scanid 10464 not found on Flywheel.
# Warning: scanid 10707 not found on Flywheel.
# Warning: scanid 10469 not found on Flywheel.
# Warning: scanid 10470 not found on Flywheel.
# Warning: scanid 10475 not found on Flywheel.
# Warning: scanid 10476 not found on Flywheel.
# Warning: scanid 11339 not found on Flywheel.
# Warning: scanid 10485 not found on Flywheel.
# Warning: scanid 10484 not found on Flywheel.
# Warning: scanid 10488 not found on Flywheel.
# Warning: scanid 10489 not found on Flywheel.
# Warning: scanid 10507 not found on Flywheel.
# Warning: scanid 10506 not found on Flywheel.
# Warning: scanid 10517 not found on Flywheel.
# Warning: scanid 10518 not found on Flywheel.
# Warning: scanid 10521 not found on Flywheel.
# Warning: scanid 10522 not found on Flywheel.
# Warning: scanid 10528 not found on Flywheel.
# Warning: scanid 10529 not found on Flywheel.
# Warning: scanid 10498 not found on Flywheel.
# Warning: scanid 10499 not found on Flywheel.
# Warning: scanid 10544 not found on Flywheel.
# Warning: scanid 10545 not found on Flywheel.
# Warning: scanid 10560 not found on Flywheel.
# Warning: scanid 10559 not found on Flywheel.
# Warning: scanid 10588 not found on Flywheel.
# Warning: scanid 10589 not found on Flywheel.
# Warning: scanid 10592 not found on Flywheel.
# Warning: scanid 10591 not found on Flywheel.
# Warning: scanid 10609 not found on Flywheel.
# Warning: scanid 10610 not found on Flywheel.
# Warning: scanid 10611 not found on Flywheel.
# Warning: scanid 10615 not found on Flywheel.
# Warning: scanid 10614 not found on Flywheel.
# Warning: scanid 10618 not found on Flywheel.
# Warning: scanid 10617 not found on Flywheel.
# Warning: scanid 10620 not found on Flywheel.
# Warning: scanid 10621 not found on Flywheel.
# Warning: scanid 10623 not found on Flywheel.
# Warning: scanid 10622 not found on Flywheel.
# Warning: scanid 10731 not found on Flywheel.
# Warning: scanid 10819 not found on Flywheel.
# Warning: scanid 10629 not found on Flywheel.
# Warning: scanid 10628 not found on Flywheel.
# Warning: scanid 10637 not found on Flywheel.
# Warning: scanid 10636 not found on Flywheel.
# Warning: scanid 10631 not found on Flywheel.
# Warning: scanid 10630 not found on Flywheel.
# Warning: scanid 10639 not found on Flywheel.
# Warning: scanid 10638 not found on Flywheel.
# Warning: scanid 10645 not found on Flywheel.
# Warning: scanid 10646 not found on Flywheel.
# Warning: scanid 10668 not found on Flywheel.
# Warning: scanid 10667 not found on Flywheel.
# Warning: scanid 10651 not found on Flywheel.
# Warning: scanid 10652 not found on Flywheel.
# Warning: scanid 10653 not found on Flywheel.
# Warning: scanid 10654 not found on Flywheel.
# Warning: scanid 10657 not found on Flywheel.
# Warning: scanid 10658 not found on Flywheel.
# Warning: scanid 10655 not found on Flywheel.
# Warning: scanid 10656 not found on Flywheel.
# Warning: scanid 10659 not found on Flywheel.
# Warning: scanid 10660 not found on Flywheel.
# Warning: scanid 10661 not found on Flywheel.
# Warning: scanid 10662 not found on Flywheel.
# Warning: scanid 10647 not found on Flywheel.
# Warning: scanid 10648 not found on Flywheel.
# Warning: scanid 10649 not found on Flywheel.
# Warning: scanid 10650 not found on Flywheel.
# Warning: scanid 10735 not found on Flywheel.
# Warning: scanid 10737 not found on Flywheel.
# Warning: scanid 10736 not found on Flywheel.
# Warning: scanid 10755 not found on Flywheel.
# Warning: scanid 10756 not found on Flywheel.
# Warning: scanid 10789 not found on Flywheel.
# Warning: scanid 10827 not found on Flywheel.
# Warning: scanid 11106 not found on Flywheel.
# Warning: scanid 10829 not found on Flywheel.
# Warning: scanid 10828 not found on Flywheel.
# Warning: scanid 10845 not found on Flywheel.
# Warning: scanid 10844 not found on Flywheel.
# Warning: scanid 10888 not found on Flywheel.
# Warning: scanid 11259 not found on Flywheel.
# Warning: scanid 11271 not found on Flywheel.
# Warning: scanid 11261 not found on Flywheel.
# Warning: scanid 11272 not found on Flywheel.
# Warning: scanid 11260 not found on Flywheel.
# Warning: scanid 11274 not found on Flywheel.
# Warning: scanid 11281 not found on Flywheel.
# Warning: scanid 11331 not found on Flywheel.
# Warning: No T1w image found for session: 9127!
# ['B0map_v4_11_e2.nii.gz', 'B0map_v4_11_e1.nii.gz', 'B0map_v4_11.nii.gz', 'B0map_v4_11_e2_Eq_1.nii.gz', 'DTI_2x32_35_14.nii.gz', 'DTI_64Combined_MB2_v2_10.nii.gz', 'localizer_1_i00003.nii.gz', 'localizer_1_i00002.nii.gz', 'localizer_1_i00001.nii.gz', 'DTI_2x32_36_15.nii.gz', 'bbl1_idemo2_210_9.nii.gz', 'bbl1_frac2back1_231_8.nii.gz', 'ep2d_se_pcasl_PHC_1200ms_6.nii.gz', 'epi_singlerep_advshim_7.nii.gz', 'ep2d_se_pcasl_PHC_1200ms_5.nii.gz', 'bbl1_restbold1_124_13.nii.gz', 'MPRAGE_TI1110_ipat2_moco3_3.nii.gz', 'MPRAGE_NAVprotocol_2.nii.gz', 'B0map_v4_12_ph.nii.gz']
# Warning: scanid 10330 not found on Flywheel.
# Warning: scanid 10712 not found on Flywheel.
# Warning: scanid 10989 not found on Flywheel.
# Warning: scanid 10738 not found on Flywheel.
# Warning: scanid 10502 not found on Flywheel.
# Warning: scanid 10418 not found on Flywheel.
# Warning: scanid 11109 not found on Flywheel.
# Warning: scanid 10087 not found on Flywheel.
# Warning: scanid 8777 not found on Flywheel.
# Warning: scanid 10706 not found on Flywheel.
# Warning: scanid 11186 not found on Flywheel.
# Warning: Multiple T1w images found for session: 010143!
# Warning: scanid 10350 not found on Flywheel.
# Warning: scanid 9132 not found on Flywheel.
# Warning: scanid 10944 not found on Flywheel.
# Warning: scanid 9457 not found on Flywheel.
# Warning: scanid 9391 not found on Flywheel.
# Warning: scanid 9459 not found on Flywheel.
# Warning: scanid 10404 not found on Flywheel.
# Warning: scanid 10933 not found on Flywheel.
# Warning: scanid 10951 not found on Flywheel.
# Warning: scanid 10764 not found on Flywheel.
# Warning: scanid 9704 not found on Flywheel.
# Warning: scanid 10314 not found on Flywheel.
# Warning: scanid 10673 not found on Flywheel.
# Warning: scanid 11194 not found on Flywheel.
# Warning: scanid 11248 not found on Flywheel.
# Warning: scanid 10318 not found on Flywheel.
# Warning: scanid 9085 not found on Flywheel.
# Warning: scanid 11100 not found on Flywheel.
# Warning: scanid 9781 not found on Flywheel.
# Warning: scanid 10901 not found on Flywheel.
# Warning: scanid 11148 not found on Flywheel.
# Warning: scanid 8946 not found on Flywheel.
# Warning: scanid 8801 not found on Flywheel.
# Warning: scanid 9063 not found on Flywheel.
# Warning: scanid 10962 not found on Flywheel.
# Warning: scanid 10902 not found on Flywheel.
# Warning: scanid 9579 not found on Flywheel.
# Warning: scanid 9030 not found on Flywheel.
# Warning: scanid 10907 not found on Flywheel.
# Warning: scanid 9333 not found on Flywheel.
# Warning: scanid 10313 not found on Flywheel.
# Warning: scanid 11133 not found on Flywheel.
# Warning: No T1w image found for session: 11394!
# ['ABCD_T1w_MPR_vNav_4_i00097.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00065.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00001.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00225.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00193.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00161.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00129.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00289.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00257.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00705.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00737.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00641.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00673.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00833.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00769.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00417.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00385.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00353.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00321.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00545.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00513.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00481.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00449.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00609.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00577.nii.gz', 'ABCD_T1w_MPR_vNav_4_i00801.nii.gz', 'localizer_32ch_2_i00003.nii.gz', 'localizer_32ch_2_i00002.nii.gz', 'localizer_32ch_2_i00001.nii.gz', 'ABCD_T1w_MPR_vNav_setter_3.nii.gz']
# Warning: scanid 10440 not found on Flywheel.
# Warning: scanid 10683 not found on Flywheel.
# Warning: scanid 11090 not found on Flywheel.
# Warning: scanid 11022 not found on Flywheel.
# Warning: scanid 10981 not found on Flywheel.
# Warning: scanid 9087 not found on Flywheel.
# Warning: scanid 10157 not found on Flywheel.
# Warning: scanid 8860 not found on Flywheel.
# Warning: scanid 9146 not found on Flywheel.
# Warning: scanid 10427 not found on Flywheel.
# Warning: scanid 10765 not found on Flywheel.
# Warning: scanid 10938 not found on Flywheel.
# Warning: scanid 10694 not found on Flywheel.
# Warning: scanid 9203 not found on Flywheel.
# Warning: scanid 10927 not found on Flywheel.
# Warning: scanid 10486 not found on Flywheel.
# Warning: scanid 11284 not found on Flywheel.
# Warning: Multiple T1w images found for session: 11623!
# Warning: scanid 11263 not found on Flywheel.
# Warning: scanid 11096 not found on Flywheel.
# Warning: scanid 11114 not found on Flywheel.
# Warning: scanid 10487 not found on Flywheel.
# Warning: scanid 10509 not found on Flywheel.
# Warning: scanid 9010 not found on Flywheel.
# Warning: scanid 10086 not found on Flywheel.
# Warning: scanid 11091 not found on Flywheel.
# Warning: scanid 9031 not found on Flywheel.
# Warning: scanid 10675 not found on Flywheel.
# Warning: scanid 11232 not found on Flywheel.
# Warning: scanid 9332 not found on Flywheel.
# Warning: scanid 8835 not found on Flywheel.
# Warning: scanid 10791 not found on Flywheel.
# Warning: scanid 11122 not found on Flywheel.
# Warning: No T1w image found for session: 10333!
# ['DTI_MultiShell_117dir_16.nii.gz', 'DTI_MultiShell_117dir_15.nii.gz', 'ASL_3DSpiral_OnlineRecon_19_Eq_1.nii.gz', 'ASL_3DSpiral_OnlineRecon_19.nii.gz', 'B0map_8_e2.nii.gz', 'B0map_8_e1.nii.gz', 'ASL_3DSpiral_OnlineRecon_21.nii.gz', 'TOF_3D_multi-slab_R2_5.nii.gz', 'T2_sagittal_SPACE_3.nii.gz', 'TOF_3D_multi-slab_R2_7.nii.gz', 'TOF_3D_multi-slab_R2_4.nii.gz', 'B0map_9_ph.nii.gz', 'TOF_3D_multi-slab_R2_6.nii.gz', 'ASL_3DSpiral_OnlineRecon_20.nii.gz', 'bbl1_fracback1_231mb_18.nii.gz', 'ASL_3DSpiral_OnlineRecon_13.nii.gz', 'ASL_3DSpiral_OnlineRecon_14.nii.gz', 'ASL_3DSpiral_OnlineRecon_12.nii.gz', 'bbl1_restbold1_124mb_11.nii.gz', 'restingBOLD_mb6_1200_10.nii.gz', 'DTI_MultiShell_topup_ref_17.nii.gz']
# Warning: scanid 7049 not found on Flywheel.
# Warning: scanid 8900 not found on Flywheel.
# Warning: Multiple T1w images found for session: 11551!
# Warning: scanid 10699 not found on Flywheel.
# ('22q_Midline_834246', '60d248f7907b39f14feb1b64', '1.3.12.2.1107.5.2.43.167024.2021062216225749568518984.0.0.0.nii.gz')
# Warning: scanid 8945 not found on Flywheel.
# Warning: scanid 8980 not found on Flywheel.
# Warning: scanid 10441 not found on Flywheel.
# Warning: scanid 10664 not found on Flywheel.
# Warning: scanid 8979 not found on Flywheel.
# Warning: scanid 11157 not found on Flywheel.
# Warning: scanid 10442 not found on Flywheel.
# Warning: scanid 8892 not found on Flywheel.
# Warning: scanid 9086 not found on Flywheel.
# Warning: scanid 10405 not found on Flywheel.
# Warning: scanid 10453 not found on Flywheel.
# Warning: scanid 11135 not found on Flywheel.
# Warning: scanid 9460 not found on Flywheel.
# Warning: scanid 10346 not found on Flywheel.
# Warning: scanid 8001 not found on Flywheel.
# Warning: scanid 10686 not found on Flywheel.
# Warning: scanid 8753 not found on Flywheel.
# Warning: Multiple T1w images found for session: 11598!
# Warning: scanid 10501 not found on Flywheel.
# Warning: scanid 10705 not found on Flywheel.
# Warning: scanid 9029 not found on Flywheel.
# Warning: scanid 10722 not found on Flywheel.
# Warning: scanid 8754 not found on Flywheel.
# Warning: scanid 8859 not found on Flywheel.
# Warning: scanid 9185 not found on Flywheel.
# Warning: scanid 10851 not found on Flywheel.
# Warning: scanid 8574 not found on Flywheel.
# ('NEFF_818028', '5c9e6636f546b60027ef06c8', 'MPRAGE_TI1100_ipat2_2.nii.gz')
# Warning: scanid 8987 not found on Flywheel.
# Warning: scanid 10293 not found on Flywheel.
# Warning: scanid 10688 not found on Flywheel.
# Warning: scanid 10701 not found on Flywheel.
# Warning: scanid 10700 not found on Flywheel.
# Warning: scanid 10710 not found on Flywheel.
# Warning: scanid 10711 not found on Flywheel.
# ('CONTE_815814', '5c915da3f546b6002fbea140', 'MPRAGE_TI1110_ipat2_moco3_4.nii.gz')
# Warning: scanid 10479 not found on Flywheel.
# ('MOTIVE', '604929dda84421cf17c8508a', '1.3.12.2.1107.5.2.43.167024.2021031015083796822591831.0.0.0.nii.gz')
# Warning: scanid 8205 not found on Flywheel.
# Warning: scanid 10841 not found on Flywheel.
# Warning: scanid 10842 not found on Flywheel.
# Warning: scanid 10848 not found on Flywheel.
# Warning: scanid 10847 not found on Flywheel.
# Warning: scanid 10972 not found on Flywheel.
# Warning: scanid 10906 not found on Flywheel.
# Warning: scanid 8094 not found on Flywheel.
# Warning: scanid 9558 not found on Flywheel.
# Warning: scanid 9727 not found on Flywheel.
# Warning: scanid 9726 not found on Flywheel.
# Warning: scanid 10760 not found on Flywheel.
# Warning: scanid 8534 not found on Flywheel.
# Warning: scanid 10692 not found on Flywheel.
# ('PNC_LG_810336', '5c77141bba258000393a0977', 'MPRAGE_TI1110_ipat2_moco3_4.nii.gz')
# Warning: scanid 9204 not found on Flywheel.
# Warning: scanid 8985 not found on Flywheel.
# Warning: scanid 10739 not found on Flywheel.

# %% [markdown]
# # Step 5: Locating Scans on Flywheel - RESULTS
# ## Tried to located `2297` scans
# ## Sucessfully located `2174` scans
# ## Failed to located `483`

# %%
xl
# Out:
#        bblid  scanid   sesid                  scan_protocol    project  \
# 0      10180    3931     NaN                  808799 - DAY2        NaN
# 1      10180    4451     NaN          807360 - Olf Lifespan        NaN
# 2      10410    6776  FNDM11                  810211 - FNDM  ExtraLong
# 3      10410    6843  FNDM21                  810211 - FNDM  ExtraLong
# 4      11176    4185     NaN                  808799 - DAY2        NaN
# ...      ...     ...     ...                            ...        ...
# 3107  139272   10739     NaN  825940 - GluCEST in Psychosis        NaN
# 3108  139490    8461    PNC1                810336 - Big GO  ExtraLong
# 3109  139490   10564  CONTE1                 815814 - Conte  ExtraLong
# 3110  139553    8410    PNC1                810336 - Big GO  ExtraLong
# 3111  139553    9822    PNC2                   810336 - Go3  ExtraLong
#
#                                        filename                     acqid  \
# 0
# 1
# 2               sub-10410_ses-FNDM11_T1w.nii.gz  5d9e0666a54d350038b39e11
# 3               sub-10410_ses-FNDM21_T1w.nii.gz  5d9e0972a54d350044c11e33
# 4
# ...                                         ...                       ...
# 3107
# 3108             sub-139490_ses-PNC1_T1w.nii.gz  5d9cd114a54d350039b28ece
# 3109  sub-139490_ses-CONTE1_acq-moco_T1w.nii.gz  5d9ca3cfa54d350028b04b1d
# 3110             sub-139553_ses-PNC1_T1w.nii.gz  5d9d14b1a54d350042bcbddd
# 3111             sub-139553_ses-PNC2_T1w.nii.gz  5d9f6460ccb6a50054468422
#
#          doscan  timepoint  ntimepoints  scanage_months  sex  race  ethnic
# 0    2010-10-11          1            2           566.0  1.0   2.0     2.0
# 1    2011-01-31          2            2           569.0  1.0   2.0     2.0
# 2    2012-04-24          1            2           556.0  2.0   2.0     2.0
# 3    2012-05-11          2            2           557.0  2.0   2.0     2.0
# 4    2010-11-23          1            2           337.0  1.0   1.0     2.0
# ...         ...        ...          ...             ...  ...   ...     ...
# 3107 2018-03-29          8            8           282.0  2.0   2.0     2.0
# 3108 2013-08-30          1            2           105.0  1.0   2.0     2.0
# 3109 2017-04-29          2            2           149.0  1.0   2.0     2.0
# 3110 2013-08-23          1            2           107.0  2.0   2.0     2.0
# 3111 2015-09-12          2            2           132.0  2.0   2.0     2.0
#
# [3112 rows x 14 columns]

# %%
useCounts
# Out:
# {<function __main__.find_by_mprage_in_fname(acq)>: 0,
#  <function __main__.find_by_acq_label(acq)>: 0,
#  <function __main__.find_by_other_fname(acq)>: 0}

# %%
foundproj = xl[(xl.acqid == "")].copy()
foundT1w = xl[xl.acqid != ""].copy()

print(f'Tried to located {len(xl)} scans on Flywheel.')
print(f'Found {len(foundT1w)} T1w scans.')
print(f'Failed to find {len(failed)} scans.')
#print(f"Number of subjects: {len(freeze.bblid.unique())}")

print(f'\nScans that were located, broken down by project:')
foundT1w.value_counts('project')
# Out:
# Tried to located 3112 scans on Flywheel.
# Found 2622 T1w scans.
# Found 490 sessions without T1w scans.
# Failed to find 490 scans.
#
# Scans that were located, broken down by project:
# project
# ExtraLong             2339
# MOTIVE                 102
# Evolution_833922        74
# NEFF_818028             39
# PNC_CS_810336           27
# 22q_Midline_834246      22
# EONSX_810366             8
# PNC_LG_810336            3
# GRMPY_822831             3
# SYRP_818621              2
# AGGY_808689              2
# CONTE_815814             1
# dtype: int64

# %%
# Debugging failed cases
failed_bc_deprecated = failed[failed.scan_protocol.isin(DEPRECATED_PROTOCOLS)]
failed_bc_multiple = failed[failed.filename == 'multiple']
failed_bc_other = failed[(~failed.scanid.isin(failed_bc_multiple.scanid)) & (~failed.scanid.isin(failed_bc_deprecated.scanid))]
print(f'{len(failed)} scans failed')
print(f'{len(failed_bc_deprecated)} scans failed because project is deprecated')
print(f'{len(failed_bc_multiple)} scans failed due to multiple t1w images found')
print(f'{len(failed_bc_other)} scans failed bc other')


#failed = failed.drop(failed[~failed.scanid.isin(failed2.scanid)].index)
#
# Out:
# 490 scans failed
# 443 scans failed because project is deprecated
# 6 scans failed due to multiple t1w images found
# 41 scans failed bc other

# %%
print(f'Scans that were not located, broken down by project:')
failed.value_counts('scan_protocol')
# Out:
# Scans that were not located, broken down by project:
# scan_protocol
# 820690 - phASL                   119
# 816275 - ONM                     108
# 807360 - Olf Lifespan             73
# 808922 - MGI2_PENN                35
# 825834 - satterttPiloting         31
# 808799 - DAY2                     24
# 818028 - Effort                   23
# 825940 - GluCEST in Psychosis     18
# 822937 - HARMONY                  16
# 818621 - SYRP                     15
# 817628 - EFDO                     10
# 829502 - MOTIVE                   10
# 810336 - Go3                       6
# 810211 - FNDM                      6
# B10218 - MGI2_PITT                 6
# 822831 - GRMPY                     4
# 816281 - NODRA                     3
# 815814 - Conte                     3
# 810336 - Go2 Supplement            3
# 833922 - EvolPsy                   3
# 834246 - 22qmidline                1
# 808689 - AGGY                      1
# dtype: int64

# %%
# 1. Final filter on resulting dataframe to only include subjects with 2+ scans on Flywheel.
freeze = filterBySessionCount(foundT1w,2)

# 2. Filter by data freeze threshold date
freeze = freeze[freeze.doscan >= earliest]
freeze
# Out:
#        bblid  scanid   sesid    scan_protocol    project  \
# 2      10410    6776  FNDM11    810211 - FNDM  ExtraLong
# 3      10410    6843  FNDM21    810211 - FNDM  ExtraLong
# 7      11186    3395   DAY21    808799 - DAY2  ExtraLong
# 8      11186    6378  FNDM21    810211 - FNDM  ExtraLong
# 10     11242    3360   DAY21    808799 - DAY2  ExtraLong
# ...      ...     ...     ...              ...        ...
# 3106  139272   10109   10109   822831 - GRMPY  ExtraLong
# 3108  139490    8461    PNC1  810336 - Big GO  ExtraLong
# 3109  139490   10564  CONTE1   815814 - Conte  ExtraLong
# 3110  139553    8410    PNC1  810336 - Big GO  ExtraLong
# 3111  139553    9822    PNC2     810336 - Go3  ExtraLong
#
#                                        filename                     acqid  \
# 2               sub-10410_ses-FNDM11_T1w.nii.gz  5d9e0666a54d350038b39e11
# 3               sub-10410_ses-FNDM21_T1w.nii.gz  5d9e0972a54d350044c11e33
# 7                sub-11186_ses-DAY21_T1w.nii.gz  5d9dfb8ba54d350042bd8142
# 8               sub-11186_ses-FNDM21_T1w.nii.gz  5d9e0c47a54d350042bd95b4
# 10               sub-11242_ses-DAY21_T1w.nii.gz  5d9dfb97a54d35003eb7f374
# ...                                         ...                       ...
# 3106            sub-139272_ses-10109_T1w.nii.gz  5d9cac7ea54d35003eb749f4
# 3108             sub-139490_ses-PNC1_T1w.nii.gz  5d9cd114a54d350039b28ece
# 3109  sub-139490_ses-CONTE1_acq-moco_T1w.nii.gz  5d9ca3cfa54d350028b04b1d
# 3110             sub-139553_ses-PNC1_T1w.nii.gz  5d9d14b1a54d350042bcbddd
# 3111             sub-139553_ses-PNC2_T1w.nii.gz  5d9f6460ccb6a50054468422
#
#          doscan  timepoint  ntimepoints  scanage_months  sex  race  ethnic
# 2    2012-04-24          1            2           556.0  2.0   2.0     2.0
# 3    2012-05-11          2            2           557.0  2.0   2.0     2.0
# 7    2010-06-10          1            2           534.0  1.0   1.0     2.0
# 8    2012-02-03          2            2           554.0  1.0   1.0     2.0
# 10   2010-06-02          1            2           694.0  1.0   1.0     2.0
# ...         ...        ...          ...             ...  ...   ...     ...
# 3106 2016-04-07          6            6           259.0  2.0   2.0     2.0
# 3108 2013-08-30          1            2           105.0  1.0   2.0     2.0
# 3109 2017-04-29          2            2           149.0  1.0   2.0     2.0
# 3110 2013-08-23          1            2           107.0  2.0   2.0     2.0
# 3111 2015-09-12          2            2           132.0  2.0   2.0     2.0
#
# [2592 rows x 14 columns]

# %% [markdown]
# # Step 6: Export final datafreeze as csv

# %%
freeze.sort_values(by=['bblid','doscan'],inplace=True)
fname = f"./csv/ExtraLong-datafreeze-{cutoff_date.isoformat()}.csv"
freeze.to_csv(f"./csv/ExtraLong-Datafreeze-20210831.csv", index=False)

# %%
freeze[freeze.acqid != ""]
# Out:
#        bblid  scanid   sesid    scan_protocol      project  \
# 16     11399    8767     NaN  818028 - Effort  NEFF_818028
# 26     11599    8555     NaN  818028 - Effort  NEFF_818028
# 35     11801    8591     NaN  818028 - Effort  NEFF_818028
# 54     12202    8751     NaN  818028 - Effort  NEFF_818028
# 104    13190    9846   NEFF1  818028 - Effort    ExtraLong
# ...      ...     ...     ...              ...          ...
# 3106  139272   10109   10109   822831 - GRMPY    ExtraLong
# 3108  139490    8461    PNC1  810336 - Big GO    ExtraLong
# 3109  139490   10564  CONTE1   815814 - Conte    ExtraLong
# 3110  139553    8410    PNC1  810336 - Big GO    ExtraLong
# 3111  139553    9822    PNC2     810336 - Go3    ExtraLong
#
#                                        filename                     acqid  \
# 16                 MPRAGE_TI1100_ipat2_2.nii.gz  5c9e6630f546b6002aef9013
# 26                 MPRAGE_TI1100_ipat2_3.nii.gz  5c9e663bf546b6002aef904d
# 35                 MPRAGE_TI1100_ipat2_2.nii.gz  5c9e6639f546b60028eee5e1
# 54                 MPRAGE_TI1100_ipat2_2.nii.gz  5c9e6630f546b60039efc75b
# 104     sub-13190_ses-NEFF1_acq-moco_T1w.nii.gz  5d9e055ba54d35003eb7f94c
# ...                                         ...                       ...
# 3106            sub-139272_ses-10109_T1w.nii.gz  5d9cac7ea54d35003eb749f4
# 3108             sub-139490_ses-PNC1_T1w.nii.gz  5d9cd114a54d350039b28ece
# 3109  sub-139490_ses-CONTE1_acq-moco_T1w.nii.gz  5d9ca3cfa54d350028b04b1d
# 3110             sub-139553_ses-PNC1_T1w.nii.gz  5d9d14b1a54d350042bcbddd
# 3111             sub-139553_ses-PNC2_T1w.nii.gz  5d9f6460ccb6a50054468422
#
#          doscan  timepoint  ntimepoints  scanage_months  sex  race  ethnic
# 16   2014-02-27          4            4           458.0  2.0   2.0     2.0
# 26   2013-10-07          3            3           521.0  2.0   2.0     2.0
# 35   2013-10-23          3            3           399.0  1.0   1.0     2.0
# 54   2014-02-18          3            3           412.0  2.0   2.0     2.0
# 104  2015-09-22          4            4           388.0  1.0   1.0     2.0
# ...         ...        ...          ...             ...  ...   ...     ...
# 3106 2016-04-07          6            6           259.0  2.0   2.0     2.0
# 3108 2013-08-30          1            2           105.0  1.0   2.0     2.0
# 3109 2017-04-29          2            2           149.0  1.0   2.0     2.0
# 3110 2013-08-23          1            2           107.0  2.0   2.0     2.0
# 3111 2015-09-12          2            2           132.0  2.0   2.0     2.0
#
# [2159 rows x 14 columns]

# %%
import string 

SESSION_LABEL_DICT = {
    "22q_Midline_834246": "22QMID",
    "AGGY_808689": "AGGY",
    "CONTE_815814": "CONTE",
    "EONSX_810366": "EONSX",
    "GRMPY_822831": "GRMPY",
    "MOTIVE": "MOTIVE",
    "NEFF_818028": "NEFF",
    "PNC_CS_810336": "PNC",
    "PNC_LG_810336": "PNC",
    "SYRP_818621": "SYRP",
    "Evolution_833922": "EVOL"
}

# Clean the sesid field for the entire dataframe
for index,scan in freeze.iterrows():
    
    sesid = str(scan.sesid)
    # Check for existing ses label
    
    # All numeric sesid's from old ExtraLong should be GRMPY
    if sesid.isdecimal():
        new = "GRMPY"
    # Change motive to all caps to match

    elif sesid == 'motive1':
        new = "MOTIVE"
    
    elif sesid.lower() == 'nan':
        new = SESSION_LABEL_DICT[scan.project]
    
    else:
        new = sesid.rstrip(string.digits)
    
    freeze.loc[index, "sesid"] = new
freeze
# Out:
#        bblid  scanid  sesid    scan_protocol    project  \
# 2      10410    6776   FNDM    810211 - FNDM  ExtraLong
# 3      10410    6843   FNDM    810211 - FNDM  ExtraLong
# 7      11186    3395    DAY    808799 - DAY2  ExtraLong
# 8      11186    6378   FNDM    810211 - FNDM  ExtraLong
# 10     11242    3360    DAY    808799 - DAY2  ExtraLong
# ...      ...     ...    ...              ...        ...
# 3106  139272   10109  GRMPY   822831 - GRMPY  ExtraLong
# 3108  139490    8461    PNC  810336 - Big GO  ExtraLong
# 3109  139490   10564  CONTE   815814 - Conte  ExtraLong
# 3110  139553    8410    PNC  810336 - Big GO  ExtraLong
# 3111  139553    9822    PNC     810336 - Go3  ExtraLong
#
#                                        filename                     acqid  \
# 2               sub-10410_ses-FNDM11_T1w.nii.gz  5d9e0666a54d350038b39e11
# 3               sub-10410_ses-FNDM21_T1w.nii.gz  5d9e0972a54d350044c11e33
# 7                sub-11186_ses-DAY21_T1w.nii.gz  5d9dfb8ba54d350042bd8142
# 8               sub-11186_ses-FNDM21_T1w.nii.gz  5d9e0c47a54d350042bd95b4
# 10               sub-11242_ses-DAY21_T1w.nii.gz  5d9dfb97a54d35003eb7f374
# ...                                         ...                       ...
# 3106            sub-139272_ses-10109_T1w.nii.gz  5d9cac7ea54d35003eb749f4
# 3108             sub-139490_ses-PNC1_T1w.nii.gz  5d9cd114a54d350039b28ece
# 3109  sub-139490_ses-CONTE1_acq-moco_T1w.nii.gz  5d9ca3cfa54d350028b04b1d
# 3110             sub-139553_ses-PNC1_T1w.nii.gz  5d9d14b1a54d350042bcbddd
# 3111             sub-139553_ses-PNC2_T1w.nii.gz  5d9f6460ccb6a50054468422
#
#          doscan  timepoint  ntimepoints  scanage_months  sex  race  ethnic
# 2    2012-04-24          1            2           556.0  2.0   2.0     2.0
# 3    2012-05-11          2            2           557.0  2.0   2.0     2.0
# 7    2010-06-10          1            2           534.0  1.0   1.0     2.0
# 8    2012-02-03          2            2           554.0  1.0   1.0     2.0
# 10   2010-06-02          1            2           694.0  1.0   1.0     2.0
# ...         ...        ...          ...             ...  ...   ...     ...
# 3106 2016-04-07          6            6           259.0  2.0   2.0     2.0
# 3108 2013-08-30          1            2           105.0  1.0   2.0     2.0
# 3109 2017-04-29          2            2           149.0  1.0   2.0     2.0
# 3110 2013-08-23          1            2           107.0  2.0   2.0     2.0
# 3111 2015-09-12          2            2           132.0  2.0   2.0     2.0
#
# [2592 rows x 14 columns]

# %%
# comparison of old vs new run
oldFailed = pd.read_csv('./csv/scans-not-found-on-flywheel.csv')

common = failed.merge(oldFailed,on=['scanid'])

found = oldFailed[(~oldFailed.scanid.isin(common.scanid))]
found.to_csv('additional_found _scans.csv',index=False)
found
# Out:
#       bblid  scanid  sesid         scan_protocol  project  projectid  \
# 477  128079   11639    NaN      833922 - EvolPsy      NaN        NaN
# 478   89279   11550    NaN   834246 - 22qmidline      NaN        NaN
# 479   89279   11699    NaN  843329 - LongGluCEST      NaN        NaN
# 480   91422   11753    NaN  843329 - LongGluCEST      NaN        NaN
# 481  111720   11766    NaN  843329 - LongGluCEST      NaN        NaN
# 482  114738   11706    NaN  843329 - LongGluCEST      NaN        NaN
# 483  115783   11788    NaN  843329 - LongGluCEST      NaN        NaN
# 484  116354   11774    NaN  843329 - LongGluCEST      NaN        NaN
# 485  118864   11783    NaN  843329 - LongGluCEST      NaN        NaN
# 486  121085   11716    NaN  843329 - LongGluCEST      NaN        NaN
#
#          doscan  timepoint  ntimepoints  scanage_months  sex  race  ethnic
# 477  2021-01-27          2            3           210.0  1.0   2.0     2.0
# 478  2020-10-06         10           11           263.0  1.0   2.0     2.0
# 479  2021-03-23         11           11           268.0  1.0   2.0     2.0
# 480  2021-05-18          5            5           309.0  1.0   2.0     2.0
# 481  2021-06-03          2            2           269.0  1.0   1.0     2.0
# 482  2021-03-30          5            5           237.0  2.0   5.0     2.0
# 483  2021-06-15          3            3           323.0  2.0   2.0     2.0
# 484  2021-06-08          7            7           283.0  2.0   2.0     2.0
# 485  2021-06-14          6            6           237.0  2.0   5.0     1.0
# 486  2021-04-10         10           10           284.0  2.0   1.0     2.0
